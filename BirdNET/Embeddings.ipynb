# %%
# Import necessary libraries
import tensorflow as tf
import numpy as np

# %%
model_path = "models/CustomClassifier_Append.tflite"

# %%
import tensorflow as tf
import numpy as np

# Load the TFLite model
interpreter = tf.lite.Interpreter(model_path=model_path)
interpreter.allocate_tensors()

# Get layer details
layer_details = interpreter.get_tensor_details()

# Print layer details
for layer in layer_details:
    print("Layer Name:", layer['name'])
    print("Layer Index:", layer['index'])
    print("Layer Shape:", layer['shape'])
    print("Layer Type:", layer['dtype'])
    print("Quantization Parameters:", layer['quantization'])
    print("-" * 30)
# Out:
# Layer Name: serving_default_INPUT:0
# Layer Index: 0
# Layer Shape: [     1 144000]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BNORM_0/FusedBatchNormV3
# Layer Index: 1
# Layer Shape: [24]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_1-1_BN_2/FusedBatchNormV3_1
# Layer Index: 2
# Layer Shape: [72]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_1-2_BN_2/FusedBatchNormV3_1
# Layer Index: 3
# Layer Shape: [72]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_1-3_BN_2/FusedBatchNormV3_1
# Layer Index: 4
# Layer Shape: [72]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_2-1_BN_2/FusedBatchNormV3_1
# Layer Index: 5
# Layer Shape: [288]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_2-2_BN_2/FusedBatchNormV3_1
# Layer Index: 6
# Layer Shape: [288]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_2-3_BN_2/FusedBatchNormV3_1
# Layer Index: 7
# Layer Shape: [288]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_2-4_BN_2/FusedBatchNormV3_1
# Layer Index: 8
# Layer Shape: [288]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_3-1_BN_2/FusedBatchNormV3_1
# Layer Index: 9
# Layer Shape: [864]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_3-2_BN_2/FusedBatchNormV3_1
# Layer Index: 10
# Layer Shape: [864]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_3-3_BN_2/FusedBatchNormV3_1
# Layer Index: 11
# Layer Shape: [864]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_3-4_BN_2/FusedBatchNormV3_1
# Layer Index: 12
# Layer Shape: [864]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_3-5_BN_2/FusedBatchNormV3_1
# Layer Index: 13
# Layer Shape: [864]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-1_BN_2/FusedBatchNormV3_1
# Layer Index: 14
# Layer Shape: [1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_BN_2/FusedBatchNormV3_1
# Layer Index: 15
# Layer Shape: [1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_BN_2/FusedBatchNormV3_1
# Layer Index: 16
# Layer Shape: [1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_BN_2/FusedBatchNormV3_1
# Layer Index: 17
# Layer Shape: [1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/POST_BN_1/FusedBatchNormV3_1
# Layer Index: 18
# Layer Shape: [1024]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/POOL_0_CONV/BiasAdd/ReadVariableOp
# Layer Index: 19
# Layer Shape: [24]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_1-1_BN_1/FusedBatchNormV3
# Layer Index: 20
# Layer Shape: [72]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_1-1_BN_2/FusedBatchNormV3_1;model/BLOCK_1-1_CONV_2/depthwise_1;model/BLOCK_2-4_CONV_3/Conv2D_1
# Layer Index: 21
# Layer Shape: [ 1  3  3 72]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_2-4_CONV_3/Conv2D_1
# Layer Index: 22
# Layer Shape: [72]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_1-2_BN_1/FusedBatchNormV3_1
# Layer Index: 23
# Layer Shape: [72]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_1-2_BN_2/FusedBatchNormV3_1;model/BLOCK_1-2_CONV_2/depthwise_1;model/BLOCK_2-4_CONV_3/Conv2D_1
# Layer Index: 24
# Layer Shape: [ 1  3  3 72]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_1-3_BN_1/FusedBatchNormV3_1
# Layer Index: 25
# Layer Shape: [72]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_1-3_BN_2/FusedBatchNormV3_1;model/BLOCK_1-3_CONV_2/depthwise_1;model/BLOCK_2-4_CONV_3/Conv2D_1
# Layer Index: 26
# Layer Shape: [ 1  3  3 72]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_2-1_BN_1/FusedBatchNormV3_1
# Layer Index: 27
# Layer Shape: [288]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_2-1_BN_2/FusedBatchNormV3_1;model/BLOCK_2-1_CONV_2/depthwise_1;model/BLOCK_2-4_SE_CONV_2/Conv2D_1
# Layer Index: 28
# Layer Shape: [  1   3   3 288]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_2-4_SE_CONV_2/Conv2D_1
# Layer Index: 29
# Layer Shape: [288]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_2-2_BN_1/FusedBatchNormV3_1
# Layer Index: 30
# Layer Shape: [288]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_2-2
024]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: truediv_1;truediv_1
# Layer Index: 132
# Layer Shape: []
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/sequential_8/dense_12/BiasAdd/ReadVariableOp
# Layer Index: 133
# Layer Shape: [35]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_1-1_PAD/Pad/paddings
# Layer Index: 134
# Layer Shape: [4 2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_2-1_SE_AVG_POOL_1/Mean/reduction_indices
# Layer Index: 135
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_2-1_SE_RESHAPE/Reshape/shape/1
# Layer Index: 136
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_2-1_SE_RESHAPE/Reshape/shape/3
# Layer Index: 137
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_2-1_SE_RESHAPE/strided_slice/stack
# Layer Index: 138
# Layer Shape: [1]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_2-1_SE_RESHAPE/strided_slice/stack_1
# Layer Index: 139
# Layer Shape: [1]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_3-1_SE_RESHAPE/Reshape/shape/3
# Layer Index: 140
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-1_SE_RESHAPE/Reshape/shape/3
# Layer Index: 141
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/CLASS_DENSE_LAYER/BiasAdd/ReadVariableOp
# Layer Index: 142
# Layer Shape: [6522]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: truediv_1;truediv_11
# Layer Index: 143
# Layer Shape: []
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/hann_window/sub_2;stft/hann_window/sub_21
# Layer Index: 144
# Layer Shape: [2048]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/Reshape_3;stft/frame/Reshape_31
# Layer Index: 145
# Layer Shape: [   1 1024]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/packed;stft/frame/packed
# Layer Index: 146
# Layer Shape: [3]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/ones_like;stft/frame/ones_like
# Layer Index: 147
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/floordiv_2;stft/frame/floordiv_21
# Layer Index: 148
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: transpose/perm;transpose/perm
# Layer Index: 149
# Layer Shape: [3]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame_step;stft/frame_step1
# Layer Index: 150
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame_length;stft/frame_length1
# Layer Index: 151
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/zeros_like;stft/frame/zeros_like
# Layer Index: 152
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/Reshape/shape_1;stft/frame/Reshape/shape_1
# Layer Index: 153
# Layer Shape: [0]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/Rank;stft/frame/Rank
# Layer Index: 154
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: add/y;add/y
# Layer Index: 155
# Layer Shape: []
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: ExpandDims/dim;ExpandDims/dim
# Layer Index: 156
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Mul/y;Mul/y
# Layer Index: 157
# Layer Shape: []
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: ReverseV2/axis;ReverseV2/axis
# Layer Index: 158
# Layer Shape: [1]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Sub_1/y;Sub_1/y
# Layer Index: 159
# Layer Shape: []
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Tensordot/Const_2;Tensordot/Const_2
# Layer Index: 160
# Layer Shape: [1]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Tensordot/GatherV2/axis;Tensordot/GatherV2/axis
# Layer Index: 161
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Tensordot/free;Tensordot/free
# Layer Index: 162
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Tensordot/MatMul;Tensordot/MatMul1
# Layer Index: 163
# Layer Shape: [  96 1025]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Tensordot/MatMul;Tensordot/MatMul2
# Layer Index: 164
# Layer Shape: [ 96 513]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BNORM_SPEC_NOQUANT/FusedBatchNormV3
# Layer Index: 165
# Layer Shape: [2]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BNORM_SPEC_NOQUANT/FusedBatchNormV31
# Layer Index: 166
# Layer Shape: [2]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BNORM_POST_NOQUANT/FusedBatchNormV3_1
# Layer Index: 167
# Layer Shape: [192]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BNORM_POST_NOQUANT/FusedBatchNormV3_11
# Layer Index: 168
# Layer Shape: [192]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/CLASS_DENSE_LAYER/MatMul
# Layer Index: 169
# Layer Shape: [6522 1024]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/sequential_8/dense_12/MatMul
# Layer Index: 170
# Layer Shape: [  35 1024]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Min;Min
# Layer Index: 171
# Layer Shape: [1 1]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Sub;Sub
# Layer Index: 172
# Layer Shape: [     1 144000]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Max;Max
# Layer Index: 173
# Layer Shape: [1 1]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: add;add
# Layer Index: 174
# Layer Shape: [1 1]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: truediv;truediv
# Layer Index: 175
# Layer Shape: [     1 144000]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Sub_1;Sub_1
# Layer Index: 176
# Layer Shape: [     1 144000]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Mul;Mul
# Layer Index: 177
# Layer Shape: [     1 144000]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/Shape;stft/frame/Shape
# Layer Index: 178
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/split;stft/frame/split
# Layer Index: 179
# Layer Shape: [1]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/split;stft/frame/split1
# Layer Index: 180
# Layer Shape: [1]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/split;stft/frame/split2
# Layer Index: 181
# Layer Shape: [0]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/Reshape;stft/frame/Reshape
# Layer Index: 182
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/floordiv_3;stft/frame/floordiv_3
# Layer Index: 183
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/concat_1/values_1;stft/frame/concat_1/values_1
# Layer Index: 184
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/mul;stft/frame/mul
# Layer Index: 185
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/concat/values_1;stft/frame/concat/values_1
# Layer Index: 186
# Layer Shape: [1]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/concat;stft/frame/concat
# Layer Index: 187
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/concat_1;stft/frame/concat_1
# Layer Index: 188
# Layer Shape: [3]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/StridedSlice;stft/frame/StridedSlice
# Layer Index: 189
# Layer Shape: [1 1]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/Reshape_1;stft/frame/Reshape_1
# Layer Index: 190
# Layer Shape: [1 1 2]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/sub_2;stft/frame/sub_2
# Layer Index: 191
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/floordiv;stft/frame/floordiv
# Layer Index: 192
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/add;stft/frame/add
# Layer Index: 193
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/Maximum;stft/frame/Maximum
# Layer Index: 194
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/Reshape_2/shape;stft/frame/Reshape_2/shape
# Layer Index: 195
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/concat_2/values_1;stft/frame/concat_2/values_1
# Layer Index: 196
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/concat_2;stft/frame/concat_2
# Layer Index: 197
# Layer Shape: [3]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/range_1;stft/frame/range_1
# Layer Index: 198
# Layer Shape: [1]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/mul_1;stft/frame/mul_1
# Layer Index: 199
# Layer Shape: [1]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/Reshape_2;stft/frame/Reshape_2
# Layer Index: 200
# Layer Shape: [1 1]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/add_1;stft/frame/add_1
# Layer Index: 201
# Layer Shape: [   1 1024]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/GatherV2;stft/frame/GatherV2;model/BLOCK_2-1_SE_RESHAPE/Reshape/shape/1
# Layer Index: 202
# Layer Shape: [   1    1 1024    2]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/Reshape_4;stft/frame/Reshape_4
# Layer Index: 203
# Layer Shape: [   1    1 2048]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/mul;stft/mul
# Layer Index: 204
# Layer Shape: [   1    1 2048]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/rfft;stft/rfft3
# Layer Index: 205
# Layer Shape: [   1    1    1 2048]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/rfft;stft/rfft4
# Layer Index: 206
# Layer Shape: [   1    1    1 1025]
# Layer Type: <class 'numpy.complex64'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/rfft;stft/rfft5
# Layer Index: 207
# Layer Shape: [   1    1 1025]
# Layer Type: <class 'numpy.complex64'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Cast;Cast
# Layer Index: 208
# Layer Shape: [   1    1 1025]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Tensordot/Shape;Tensordot/Shape
# Layer Index: 209
# Layer Shape: [3]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Tensordot/GatherV2;Tensordot/GatherV2;Tensordot/GatherV2/axis;Tensordot/GatherV2/axis
# Layer Index: 210
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Tensordot/Prod;Tensordot/Prod
# Layer Index: 211
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Tensordot/concat_1;Tensordot/concat_1
# Layer Index: 212
# Layer Shape: [3]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Tensordot/GatherV2_1;Tensordot/GatherV2_1;Tensordot/GatherV2/axis;Tensordot/GatherV2/axis
# Layer Index: 213
# Layer Shape: [1]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Tensordot/Prod_1;Tensordot/Prod_1
# Layer Index: 214
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Tensordot/stack;Tensordot/stack
# Layer Index: 215
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Tensordot/Reshape;Tensordot/Reshape
# Layer Index: 216
# Layer Shape: [1 1]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Tensordot/MatMul;Tensordot/MatMul3
# Layer Index: 217
# Layer Shape: [ 1 96]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Tensordot;Tensordot
# Layer Index: 218
# Layer Shape: [ 1  1 96]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Pow;Pow;Mul/y;Mul/y
# Layer Index: 219
# Layer Shape: [ 1  1 96]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: Pow_1;Pow_1
# Layer Index: 220
# Layer Shape: [ 1  1 96]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: ReverseV2;ReverseV2
# Layer Index: 221
# Layer Shape: [ 1  1 96]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: transpose;transpose
# Layer Index: 222
# Layer Shape: [ 1 96  1]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: ExpandDims;ExpandDims
# Layer Index: 223
# Layer Shape: [ 1 96  1  1]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/floordiv_3;stft/frame/floordiv_31
# Layer Index: 224
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/concat_1/values_1;stft/frame/concat_1/values_11
# Layer Index: 225
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/mul;stft/frame/mul1
# Layer Index: 226
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/concat/values_1;stft/frame/concat/values_11
# Layer Index: 227
# Layer Shape: [1]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/concat;stft/frame/concat1
# Layer Index: 228
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/concat_1;stft/frame/concat_11
# Layer Index: 229
# Layer Shape: [3]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/StridedSlice;stft/frame/StridedSlice1
# Layer Index: 230
# Layer Shape: [1 1]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/Reshape_1;stft/frame/Reshape_11
# Layer Index: 231
# Layer Shape: [1 1 8]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/sub_2;stft/frame/sub_21
# Layer Index: 232
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/floordiv;stft/frame/floordiv1
# Layer Index: 233
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/add;stft/frame/add1
# Layer Index: 234
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/Maximum;stft/frame/Maximum1
# Layer Index: 235
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/Reshape_2/shape;stft/frame/Reshape_2/shape1
# Layer Index: 236
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/concat_2/values_1;stft/frame/concat_2/values_11
# Layer Index: 237
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/concat_2;stft/frame/concat_21
# Layer Index: 238
# Layer Shape: [3]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/range_1;stft/frame/range_11
# Layer Index: 239
# Layer Shape: [1]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/mul_1;stft/frame/mul_11
# Layer Index: 240
# Layer Shape: [1]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/Reshape_2;stft/frame/Reshape_21
# Layer Index: 241
# Layer Shape: [1 1]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/add_1;stft/frame/add_11
# Layer Index: 242
# Layer Shape: [  1 128]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/GatherV2;stft/frame/GatherV2;model/BLOCK_2-1_SE_RESHAPE/Reshape/shape/11
# Layer Index: 243
# Layer Shape: [  1   1 128   8]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/frame/Reshape_4;stft/frame/Reshape_41
# Layer Index: 244
# Layer Shape: [   1    1 1024]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/mul;stft/mul1
# Layer Index: 245
# Layer Shape: [   1    1 1024]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/rfft;stft/rfft6
# Layer Index: 246
# Layer Shape: [   1    1    1 1024]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/rfft;stft/rfft7
# Layer Index: 247
# Layer Shape: [  1   1   1 513]
# Layer Type: <class 'numpy.complex64'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: stft/rfft;stft/rfft8
# Layer Index: 248
# Layer Shape: [  1   1 513]
# Layer Type: <class 'numpy.complex64'>
# Quantization Parameters: (0.0, 0)
# ...
# ------------------------------
# Layer Name: model/BLOCK_4-1_SE_RESHAPE/Shape
# Layer Index: 476
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-1_SE_RESHAPE/strided_slice
# Layer Index: 477
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-1_SE_RESHAPE/Reshape/shape
# Layer Index: 478
# Layer Shape: [4]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-1_SE_RESHAPE/Reshape
# Layer Index: 479
# Layer Shape: [   1    1    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-1_SE_CONV_1/Conv2D
# Layer Index: 480
# Layer Shape: [ 1  1  1 48]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-1_SE_CONV_1/Sigmoid
# Layer Index: 481
# Layer Shape: [ 1  1  1 48]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-1_SE_CONV_1/mul_1
# Layer Index: 482
# Layer Shape: [ 1  1  1 48]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-1_SE_CONV_2/Conv2D
# Layer Index: 483
# Layer Shape: [   1    1    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-1_SE_CONV_2/Sigmoid
# Layer Index: 484
# Layer Shape: [   1    1    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-1_MULTIPLY/mul
# Layer Index: 485
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-1_CONV_3/Conv2D
# Layer Index: 486
# Layer Shape: [  1   3   1 192]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_BN_1/FusedBatchNormV3;model/BLOCK_4-4_SE_CONV_2/Conv2D_1;model/BLOCK_4-2_CONV_1/Conv2D;model/BLOCK_4-2_BN_1/FusedBatchNormV3_1
# Layer Index: 487
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_ACT_1/Sigmoid
# Layer Index: 488
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_ACT_1/mul_1
# Layer Index: 489
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_BN_2/FusedBatchNormV3;model/BLOCK_4-4_SE_CONV_2/Conv2D_1;model/BLOCK_4-2_CONV_2/depthwise_1;model/BLOCK_4-2_CONV_2/depthwise;model/BLOCK_4-2_BN_2/FusedBatchNormV3_1
# Layer Index: 490
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_ACT_2/Sigmoid
# Layer Index: 491
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_ACT_2/mul_1
# Layer Index: 492
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_SE_AVG_POOL_1/Mean
# Layer Index: 493
# Layer Shape: [   1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_SE_RESHAPE/Shape
# Layer Index: 494
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_SE_RESHAPE/strided_slice
# Layer Index: 495
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_SE_RESHAPE/Reshape/shape
# Layer Index: 496
# Layer Shape: [4]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_SE_RESHAPE/Reshape
# Layer Index: 497
# Layer Shape: [   1    1    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_SE_CONV_1/Conv2D
# Layer Index: 498
# Layer Shape: [ 1  1  1 48]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_SE_CONV_1/Sigmoid
# Layer Index: 499
# Layer Shape: [ 1  1  1 48]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_SE_CONV_1/mul_1
# Layer Index: 500
# Layer Shape: [ 1  1  1 48]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_SE_CONV_2/Conv2D
# Layer Index: 501
# Layer Shape: [   1    1    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_SE_CONV_2/Sigmoid
# Layer Index: 502
# Layer Shape: [   1    1    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_MULTIPLY/mul
# Layer Index: 503
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_CONV_3/Conv2D
# Layer Index: 504
# Layer Shape: [  1   3   1 192]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-2_ADD/add
# Layer Index: 505
# Layer Shape: [  1   3   1 192]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_BN_1/FusedBatchNormV3;model/BLOCK_4-4_SE_CONV_2/Conv2D_1;model/BLOCK_4-3_CONV_1/Conv2D;model/BLOCK_4-3_BN_1/FusedBatchNormV3_1
# Layer Index: 506
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_ACT_1/Sigmoid
# Layer Index: 507
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_ACT_1/mul_1
# Layer Index: 508
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_BN_2/FusedBatchNormV3;model/BLOCK_4-4_SE_CONV_2/Conv2D_1;model/BLOCK_4-3_CONV_2/depthwise_1;model/BLOCK_4-3_CONV_2/depthwise;model/BLOCK_4-3_BN_2/FusedBatchNormV3_1
# Layer Index: 509
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_ACT_2/Sigmoid
# Layer Index: 510
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_ACT_2/mul_1
# Layer Index: 511
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_SE_AVG_POOL_1/Mean
# Layer Index: 512
# Layer Shape: [   1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_SE_RESHAPE/Shape
# Layer Index: 513
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_SE_RESHAPE/strided_slice
# Layer Index: 514
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_SE_RESHAPE/Reshape/shape
# Layer Index: 515
# Layer Shape: [4]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_SE_RESHAPE/Reshape
# Layer Index: 516
# Layer Shape: [   1    1    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_SE_CONV_1/Conv2D
# Layer Index: 517
# Layer Shape: [ 1  1  1 48]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_SE_CONV_1/Sigmoid
# Layer Index: 518
# Layer Shape: [ 1  1  1 48]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_SE_CONV_1/mul_1
# Layer Index: 519
# Layer Shape: [ 1  1  1 48]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_SE_CONV_2/Conv2D
# Layer Index: 520
# Layer Shape: [   1    1    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_SE_CONV_2/Sigmoid
# Layer Index: 521
# Layer Shape: [   1    1    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_MULTIPLY/mul
# Layer Index: 522
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_CONV_3/Conv2D
# Layer Index: 523
# Layer Shape: [  1   3   1 192]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-3_ADD/add
# Layer Index: 524
# Layer Shape: [  1   3   1 192]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_BN_1/FusedBatchNormV3;model/BLOCK_4-4_SE_CONV_2/Conv2D_1;model/BLOCK_4-4_CONV_1/Conv2D;model/BLOCK_4-4_BN_1/FusedBatchNormV3_1
# Layer Index: 525
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_ACT_1/Sigmoid
# Layer Index: 526
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_ACT_1/mul_1
# Layer Index: 527
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_BN_2/FusedBatchNormV3;model/BLOCK_4-4_SE_CONV_2/Conv2D_1;model/BLOCK_4-4_CONV_2/depthwise_1;model/BLOCK_4-4_CONV_2/depthwise;model/BLOCK_4-4_BN_2/FusedBatchNormV3_1
# Layer Index: 528
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_ACT_2/Sigmoid
# Layer Index: 529
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_ACT_2/mul_1
# Layer Index: 530
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_SE_AVG_POOL_1/Mean
# Layer Index: 531
# Layer Shape: [   1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_SE_RESHAPE/Shape
# Layer Index: 532
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_SE_RESHAPE/strided_slice
# Layer Index: 533
# Layer Shape: []
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_SE_RESHAPE/Reshape/shape
# Layer Index: 534
# Layer Shape: [4]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_SE_RESHAPE/Reshape
# Layer Index: 535
# Layer Shape: [   1    1    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_SE_CONV_1/Conv2D
# Layer Index: 536
# Layer Shape: [ 1  1  1 48]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_SE_CONV_1/Sigmoid
# Layer Index: 537
# Layer Shape: [ 1  1  1 48]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_SE_CONV_1/mul_1
# Layer Index: 538
# Layer Shape: [ 1  1  1 48]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_SE_CONV_2/Conv2D
# Layer Index: 539
# Layer Shape: [   1    1    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_SE_CONV_2/Sigmoid
# Layer Index: 540
# Layer Shape: [   1    1    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_MULTIPLY/mul
# Layer Index: 541
# Layer Shape: [   1    3    1 1536]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_CONV_3/Conv2D
# Layer Index: 542
# Layer Shape: [  1   3   1 192]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BLOCK_4-4_ADD/add
# Layer Index: 543
# Layer Shape: [  1   3   1 192]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/BNORM_POST_NOQUANT/FusedBatchNormV3
# Layer Index: 544
# Layer Shape: [  1   3   1 192]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/ACT_POST/Relu;model/BNORM_POST_NOQUANT/FusedBatchNormV3
# Layer Index: 545
# Layer Shape: [  1   3   1 192]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/POST_ACT_1/Relu;model/POST_BN_1/FusedBatchNormV3;model/POST_CONV_1/Conv2D_1;model/POST_CONV_1/Conv2D;model/POST_BN_1/FusedBatchNormV3_1
# Layer Index: 546
# Layer Shape: [   1    1    1 1024]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/GLOBAL_AVG_POOL/Mean
# Layer Index: 547
# Layer Shape: [   1 1024]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/CLASS_DENSE_LAYER/MatMul;model/CLASS_DENSE_LAYER/BiasAdd
# Layer Index: 548
# Layer Shape: [   1 6522]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: model/sequential_8/dense_12/MatMul;model/sequential_8/dense_12/BiasAdd
# Layer Index: 549
# Layer Shape: [ 1 35]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name: StatefulPartitionedCall:0
# Layer Index: 550
# Layer Shape: [   1 6557]
# Layer Type: <class 'numpy.float32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name:
# Layer Index: 551
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name:
# Layer Index: 552
# Layer Shape: [1]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name:
# Layer Index: 555
# Layer Shape: [2]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------
# Layer Name:
# Layer Index: 556
# Layer Shape: [1]
# Layer Type: <class 'numpy.int32'>
# Quantization Parameters: (0.0, 0)
# ------------------------------

# %%
# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Print model summary
print("=== Model Summary ===")
print("Input details:")
for detail in input_details:
    print(detail)
print("\nOutput details:")
for detail in output_details:
    print(detail)
# Out:
# === Model Summary ===
# Input details:
# {'name': 'serving_default_INPUT:0', 'index': 0, 'shape': array([     1, 144000], dtype=int32), 'shape_signature': array([    -1, 144000], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
#
# Output details:
# {'name': 'StatefulPartitionedCall:0', 'index': 550, 'shape': array([   1, 6557], dtype=int32), 'shape_signature': array([  -1, 6557], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}

# %%
interpreter = tf.lite.Interpreter(model_path=model_path)
interpreter.allocate_tensors()

# Obtener los índices de entrada y salida
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Configurar los índices de la capa de embedding (en este caso, la capa GlobalAveragePooling)
embedding_index = 550 #547  # Índice de model/GLOBAL_AVG_POOL/Mean, como identificaste

# Asignar una entrada de prueba
input_data = np.random.random(size=input_details[0]['shape']).astype(np.float32)
interpreter.set_tensor(input_details[0]['index'], input_data)

# Ejecutar la inferencia
interpreter.invoke()

# Extraer el embedding
embedding = interpreter.get_tensor(embedding_index)
print("Embedding shape:", embedding.shape)
print("Embedding vector:", embedding)
# Out:
# Embedding shape: (1, 6557)
# Embedding vector: [[-11.844155  -15.429568  -11.689968  ...  -6.890339   -6.335218
#    -6.4139132]]
