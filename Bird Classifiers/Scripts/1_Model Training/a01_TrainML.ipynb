# %%
import numpy as np
import os

from sklearn.ensemble import RandomForestClassifier
# import xgboost as xgb
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Load Embeddings

# %%
# Load saved embeddings and labels
train_embeddings = np.load("../../../Data/Dataset/Embeddings/train_embeddings.npy", allow_pickle=True)
train_labels = np.load("../../../Data/Dataset/Embeddings/train_labels.npy", allow_pickle=True)

validation_embeddings = np.load("../../../Data/Dataset/Embeddings/validation_embeddings.npy", allow_pickle=True)
validation_labels = np.load("../../../Data/Dataset/Embeddings/validation_labels.npy", allow_pickle=True)

test_embeddings = np.load("../../../Data/Dataset/Embeddings/test_embeddings.npy", allow_pickle=True)
test_file_names = np.load("../../../Data/Dataset/Embeddings/test_file_names.npy", allow_pickle=True)
test_files_idx = np.load("../../../Data/Dataset/Embeddings/test_file_idx.npy", allow_pickle=True)

bsd_test_embeddings = np.load("../../../Data/Dataset/Embeddings/bsd_test_embeddings.npy", allow_pickle=True)
bsd_test_file_names = np.load("../../../Data/Dataset/Embeddings/bsd_test_file_names.npy", allow_pickle=True)
bsd_test_files_idx = np.load("../../../Data/Dataset/Embeddings/bsd_files_idx.npy", allow_pickle=True)

# %% [markdown]
# ## Train Classifier with embeddings

# %%
# Encode the labels
label_encoder = LabelEncoder()
train_encoded_labels = label_encoder.fit_transform(train_labels)
validation_encoded_labels = label_encoder.transform(validation_labels)

# Reshape embeddings to 2D
train_embeddings_reshaped = train_embeddings.reshape(train_embeddings.shape[0], -1)
validation_embeddings_reshaped = validation_embeddings.reshape(validation_embeddings.shape[0], -1)

# Train various RandomForest models with different configurations and take the best one
best_model = None
best_accuracy = 0

for n_estimators in [100, 200, 300, 400, 500]:
    for max_depth in [None, 10, 20, 30, 40, 50]:
        for min_samples_split in [2, 5, 10]:
            for min_samples_leaf in [1, 2, 4]:
                model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth,
                                            min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf)
                model.fit(train_embeddings_reshaped, train_encoded_labels)

                validation_predictions = model.predict(validation_embeddings_reshaped)
                accuracy = accuracy_score(validation_encoded_labels, validation_predictions)

                if accuracy > best_accuracy:
                    best_accuracy = accuracy
                    best_model = model

print("Best model accuracy: ", best_accuracy)
rf_best_model = best_model
# Out:
# Best model accuracy:  0.6243654822335025

# %%
# print best model configuration
print(rf_best_model)
# Out:
# RandomForestClassifier(max_depth=50, min_samples_leaf=2, min_samples_split=10)

# %%
# !ls ../../
# Out:
# BirdNET  Scripts  models

# %%
# Save best model
np.save("../../models/RandomForest/best_model.npy", rf_best_model)

# %% [markdown]
# ## Test Model

# %%
# Predecir etiquetas de los audios de prueba
test_predictions = rf_best_model.predict(test_embeddings.reshape(test_embeddings.shape[0], -1))

# Decodificar las etiquetas predichas
test_predictions = label_encoder.inverse_transform(test_predictions)

# Mostrar las predicciones para cada archivo
for file_name, pred, idx in zip(test_file_names, test_predictions, test_files_idx):
    print(f"Archivo: {file_name}, Predicción: {pred}, Índice: {idx}")
# Out:
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 1
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 5
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 6
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 7
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 9
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 15
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 16
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 18
# Archivo: AM1_20230530_073000.WAV, Predicción: Background, Índice: 19
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 1
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230530_061000.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 5
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 6
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 7
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 9
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 15
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 16
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 18
# Archivo: AM1_20230530_061000.WAV, Predicción: Background, Índice: 19
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 1
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 5
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 6
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 7
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 9
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 15
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 16
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 18
# Archivo: AM1_20230530_080000.WAV, Predicción: Background, Índice: 19
# Archivo: AM1_20230514_103000.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230514_103000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 1
# Archivo: AM1_20230514_103000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230514_103000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230514_103000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230514_103000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 5
# Archivo: AM1_20230514_103000.WAV, Predicción: Background, Índice: 6
# Archivo: AM1_20230514_103000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 7
# Archivo: AM1_20230514_103000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230514_103000.WAV, Predicción: Background, Índice: 9
# Archivo: AM1_20230514_103000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230514_103000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230514_103000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230514_103000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230514_103000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230514_103000.WAV, Predicción: Background, Índice: 15
# Archivo: AM1_20230514_103000.WAV, Predicción: Background, Índice: 16
# Archivo: AM1_20230514_103000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230514_103000.WAV, Predicción: Background, Índice: 18
# Archivo: AM1_20230514_103000.WAV, Predicción: Background, Índice: 19
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 1
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 5
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 6
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 7
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 9
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 15
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 16
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 18
# Archivo: AM1_20230514_110000.WAV, Predicción: Background, Índice: 19
# Archivo: AM1_20230511_063000.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230511_063000.WAV, Predicción: Background, Índice: 1
# Archivo: AM1_20230511_063000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230511_063000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230511_063000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230511_063000.WAV, Predicción: Background, Índice: 5
# Archivo: AM1_20230511_063000.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM1_20230511_063000.WAV, Predicción: Background, Índice: 7
# Archivo: AM1_20230511_063000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230511_063000.WAV, Predicción: Background, Índice: 9
# Archivo: AM1_20230511_063000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230511_063000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230511_063000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230511_063000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230511_063000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230511_063000.WAV, Predicción: Background, Índice: 15
# Archivo: AM1_20230511_063000.WAV, Predicción: Background, Índice: 16
# Archivo: AM1_20230511_063000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230511_063000.WAV, Predicción: Background, Índice: 18
# Archivo: AM1_20230511_063000.WAV, Predicción: Sturnus, Índice: 19
# Archivo: AM1_20230511_060000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM1_20230511_060000.WAV, Predicción: Background, Índice: 1
# Archivo: AM1_20230511_060000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 2
# Archivo: AM1_20230511_060000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230511_060000.WAV, Predicción: Saxicola rubicola_European Stonechat, Índice: 4
# Archivo: AM1_20230511_060000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 5
# Archivo: AM1_20230511_060000.WAV, Predicción: Background, Índice: 6
# Archivo: AM1_20230511_060000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 7
# Archivo: AM1_20230511_060000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230511_060000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 9
# Archivo: AM1_20230511_060000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230511_060000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 11
# Archivo: AM1_20230511_060000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230511_060000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230511_060000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230511_060000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 15
# Archivo: AM1_20230511_060000.WAV, Predicción: Background, Índice: 16
# Archivo: AM1_20230511_060000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230511_060000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 18
# Archivo: AM1_20230511_060000.WAV, Predicción: Background, Índice: 19
# Archivo: AM1_20230511_093000.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230511_093000.WAV, Predicción: Background, Índice: 1
# Archivo: AM1_20230511_093000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230511_093000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230511_093000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230511_093000.WAV, Predicción: Background, Índice: 5
# Archivo: AM1_20230511_093000.WAV, Predicción: Background, Índice: 6
# Archivo: AM1_20230511_093000.WAV, Predicción: Background, Índice: 7
# Archivo: AM1_20230511_093000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230511_093000.WAV, Predicción: Background, Índice: 9
# Archivo: AM1_20230511_093000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230511_093000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230511_093000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230511_093000.WAV, Predicción: Sylvia, Índice: 13
# Archivo: AM1_20230511_093000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230511_093000.WAV, Predicción: Background, Índice: 15
# Archivo: AM1_20230511_093000.WAV, Predicción: Sylvia, Índice: 16
# Archivo: AM1_20230511_093000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230511_093000.WAV, Predicción: Sylvia, Índice: 18
# Archivo: AM1_20230511_093000.WAV, Predicción: Background, Índice: 19
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 1
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 5
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 6
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 7
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 9
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 15
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 16
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 18
# Archivo: AM1_20230511_103000.WAV, Predicción: Background, Índice: 19
# Archivo: AM1_20230511_090000.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 1
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 5
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 6
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 7
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 9
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 15
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 16
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 18
# Archivo: AM1_20230511_090000.WAV, Predicción: Background, Índice: 19
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 1
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 5
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 6
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 7
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 9
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 15
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 16
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 18
# Archivo: AM1_20230512_083000.WAV, Predicción: Background, Índice: 19
# Archivo: AM1_20230512_103000.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230512_103000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 1
# Archivo: AM1_20230512_103000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230512_103000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230512_103000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230512_103000.WAV, Predicción: Background, Índice: 5
# Archivo: AM1_20230512_103000.WAV, Predicción: Background, Índice: 6
# Archivo: AM1_20230512_103000.WAV, Predicción: Background, Índice: 7
# Archivo: AM1_20230512_103000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230512_103000.WAV, Predicción: Background, Índice: 9
# Archivo: AM1_20230512_103000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230512_103000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230512_103000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230512_103000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230512_103000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230512_103000.WAV, Predicción: Background, Índice: 15
# Archivo: AM1_20230512_103000.WAV, Predicción: Background, Índice: 16
# Archivo: AM1_20230512_103000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230512_103000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 18
# Archivo: AM1_20230512_103000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 19
# Archivo: AM1_20230512_090000.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230512_090000.WAV, Predicción: Sylvia, Índice: 1
# Archivo: AM1_20230512_090000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230512_090000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230512_090000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230512_090000.WAV, Predicción: Background, Índice: 5
# Archivo: AM1_20230512_090000.WAV, Predicción: Background, Índice: 6
# Archivo: AM1_20230512_090000.WAV, Predicción: Sylvia, Índice: 7
# Archivo: AM1_20230512_090000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230512_090000.WAV, Predicción: Background, Índice: 9
# Archivo: AM1_20230512_090000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230512_090000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230512_090000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230512_090000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230512_090000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230512_090000.WAV, Predicción: Background, Índice: 15
# Archivo: AM1_20230512_090000.WAV, Predicción: Sylvia, Índice: 16
# Archivo: AM1_20230512_090000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230512_090000.WAV, Predicción: Background, Índice: 18
# Archivo: AM1_20230512_090000.WAV, Predicción: Background, Índice: 19
# Archivo: AM1_20230515_090000.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 1
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 5
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 6
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 7
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 9
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 15
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 16
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 18
# Archivo: AM1_20230515_090000.WAV, Predicción: Background, Índice: 19
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 1
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 5
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 6
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 7
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 9
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 15
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 16
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 18
# Archivo: AM1_20230515_100000.WAV, Predicción: Background, Índice: 19
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 1
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 5
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 6
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 7
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 9
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 15
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 16
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 18
# Archivo: AM1_20230515_083000.WAV, Predicción: Background, Índice: 19
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 1
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 5
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 6
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 7
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 9
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 15
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 16
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 18
# Archivo: AM1_20230510_073000.WAV, Predicción: Background, Índice: 19
# Archivo: AM1_20230510_083000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM1_20230510_083000.WAV, Predicción: Background, Índice: 1
# Archivo: AM1_20230510_083000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230510_083000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230510_083000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230510_083000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 5
# Archivo: AM1_20230510_083000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 6
# Archivo: AM1_20230510_083000.WAV, Predicción: Background, Índice: 7
# Archivo: AM1_20230510_083000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 8
# Archivo: AM1_20230510_083000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 9
# Archivo: AM1_20230510_083000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230510_083000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230510_083000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230510_083000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230510_083000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230510_083000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 15
# Archivo: AM1_20230510_083000.WAV, Predicción: Background, Índice: 16
# Archivo: AM1_20230510_083000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230510_083000.WAV, Predicción: Background, Índice: 18
# Archivo: AM1_20230510_083000.WAV, Predicción: Background, Índice: 19
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 1
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 5
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 6
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 7
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 9
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 15
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 16
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 18
# Archivo: AM1_20230510_080000.WAV, Predicción: Background, Índice: 19
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 1
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 2
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 3
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 4
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 5
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 6
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 7
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 8
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 9
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 10
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 11
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 12
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 13
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 14
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 15
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 16
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 17
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 18
# Archivo: AM1_20230510_110000.WAV, Predicción: Background, Índice: 19
# Archivo: AM10_20230718_071000.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230718_071000.WAV, Predicción: Background, Índice: 1
# Archivo: AM10_20230718_071000.WAV, Predicción: Background, Índice: 2
# Archivo: AM10_20230718_071000.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM10_20230718_071000.WAV, Predicción: Sturnus, Índice: 4
# Archivo: AM10_20230718_071000.WAV, Predicción: Sturnus, Índice: 5
# Archivo: AM10_20230718_071000.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM10_20230718_071000.WAV, Predicción: Background, Índice: 7
# Archivo: AM10_20230718_071000.WAV, Predicción: Sturnus, Índice: 8
# Archivo: AM10_20230718_071000.WAV, Predicción: Passer, Índice: 9
# Archivo: AM10_20230718_071000.WAV, Predicción: Sturnus, Índice: 10
# Archivo: AM10_20230718_071000.WAV, Predicción: Sturnus, Índice: 11
# Archivo: AM10_20230718_071000.WAV, Predicción: Sturnus, Índice: 12
# Archivo: AM10_20230718_071000.WAV, Predicción: Background, Índice: 13
# Archivo: AM10_20230718_071000.WAV, Predicción: Background, Índice: 14
# Archivo: AM10_20230718_071000.WAV, Predicción: Background, Índice: 15
# Archivo: AM10_20230718_071000.WAV, Predicción: Background, Índice: 16
# Archivo: AM10_20230718_071000.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 17
# Archivo: AM10_20230718_071000.WAV, Predicción: Sturnus, Índice: 18
# Archivo: AM10_20230718_071000.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 19
# Archivo: AM10_20230718_101000.WAV, Predicción: Background, Índice: 0
# Archivo: AM10_20230718_101000.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 1
# Archivo: AM10_20230718_101000.WAV, Predicción: Sturnus, Índice: 2
# Archivo: AM10_20230718_101000.WAV, Predicción: Background, Índice: 3
# Archivo: AM10_20230718_101000.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 4
# Archivo: AM10_20230718_101000.WAV, Predicción: Sturnus, Índice: 5
# Archivo: AM10_20230718_101000.WAV, Predicción: Saxicola rubicola_European Stonechat, Índice: 6
# Archivo: AM10_20230718_101000.WAV, Predicción: Sturnus, Índice: 7
# Archivo: AM10_20230718_101000.WAV, Predicción: Background, Índice: 8
# Archivo: AM10_20230718_101000.WAV, Predicción: Background, Índice: 9
# Archivo: AM10_20230718_101000.WAV, Predicción: Background, Índice: 10
# Archivo: AM10_20230718_101000.WAV, Predicción: Background, Índice: 11
# Archivo: AM10_20230718_101000.WAV, Predicción: Background, Índice: 12
# Archivo: AM10_20230718_101000.WAV, Predicción: Background, Índice: 13
# Archivo: AM10_20230718_101000.WAV, Predicción: Background, Índice: 14
# Archivo: AM10_20230718_101000.WAV, Predicción: Background, Índice: 15
# Archivo: AM10_20230718_101000.WAV, Predicción: Background, Índice: 16
# Archivo: AM10_20230718_101000.WAV, Predicción: Background, Índice: 17
# Archivo: AM10_20230718_101000.WAV, Predicción: Background, Índice: 18
# Archivo: AM10_20230718_101000.WAV, Predicción: Background, Índice: 19
# Archivo: AM10_20230718_094000.WAV, Predicción: Background, Índice: 0
# Archivo: AM10_20230718_094000.WAV, Predicción: Background, Índice: 1
# Archivo: AM10_20230718_094000.WAV, Predicción: Background, Índice: 2
# Archivo: AM10_20230718_094000.WAV, Predicción: Background, Índice: 3
# Archivo: AM10_20230718_094000.WAV, Predicción: Background, Índice: 4
# Archivo: AM10_20230718_094000.WAV, Predicción: Background, Índice: 5
# Archivo: AM10_20230718_094000.WAV, Predicción: Background, Índice: 6
# Archivo: AM10_20230718_094000.WAV, Predicción: Sturnus, Índice: 7
# Archivo: AM10_20230718_094000.WAV, Predicción: Background, Índice: 8
# Archivo: AM10_20230718_094000.WAV, Predicción: Background, Índice: 9
# Archivo: AM10_20230718_094000.WAV, Predicción: Background, Índice: 10
# Archivo: AM10_20230718_094000.WAV, Predicción: Background, Índice: 11
# Archivo: AM10_20230718_094000.WAV, Predicción: Background, Índice: 12
# Archivo: AM10_20230718_094000.WAV, Predicción: Background, Índice: 13
# Archivo: AM10_20230718_094000.WAV, Predicción: Background, Índice: 14
# Archivo: AM10_20230718_094000.WAV, Predicción: Carduelis carduelis_European Goldfinch, Índice: 15
# Archivo: AM10_20230718_094000.WAV, Predicción: Background, Índice: 16
# Archivo: AM10_20230718_094000.WAV, Predicción: Sturnus, Índice: 17
# Archivo: AM10_20230718_094000.WAV, Predicción: Carduelis carduelis_European Goldfinch, Índice: 18
# Archivo: AM10_20230718_094000.WAV, Predicción: Carduelis carduelis_European Goldfinch, Índice: 19
# Archivo: AM10_20230718_074000.WAV, Predicción: Carduelis carduelis_European Goldfinch, Índice: 0
# Archivo: AM10_20230718_074000.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 1
# Archivo: AM10_20230718_074000.WAV, Predicción: Carduelis carduelis_European Goldfinch, Índice: 2
# Archivo: AM10_20230718_074000.WAV, Predicción: Passer, Índice: 3
# Archivo: AM10_20230718_074000.WAV, Predicción: Sturnus, Índice: 4
# Archivo: AM10_20230718_074000.WAV, Predicción: Sturnus, Índice: 5
# Archivo: AM10_20230718_074000.WAV, Predicción: Background, Índice: 6
# Archivo: AM10_20230718_074000.WAV, Predicción: Sturnus, Índice: 7
# Archivo: AM10_20230718_074000.WAV, Predicción: Sturnus, Índice: 8
# Archivo: AM10_20230718_074000.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 9
# Archivo: AM10_20230718_074000.WAV, Predicción: Passer, Índice: 10
# Archivo: AM10_20230718_074000.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 11
# Archivo: AM10_20230718_074000.WAV, Predicción: Sturnus, Índice: 12
# Archivo: AM10_20230718_074000.WAV, Predicción: Background, Índice: 13
# Archivo: AM10_20230718_074000.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 14
# Archivo: AM10_20230718_074000.WAV, Predicción: Sturnus, Índice: 15
# Archivo: AM10_20230718_074000.WAV, Predicción: Background, Índice: 16
# Archivo: AM10_20230718_074000.WAV, Predicción: Passer, Índice: 17
# Archivo: AM10_20230718_074000.WAV, Predicción: Background, Índice: 18
# Archivo: AM10_20230718_074000.WAV, Predicción: Background, Índice: 19
# Archivo: AM10_20230718_092000.WAV, Predicción: Background, Índice: 0
# Archivo: AM10_20230718_092000.WAV, Predicción: Background, Índice: 1
# Archivo: AM10_20230718_092000.WAV, Predicción: Background, Índice: 2
# Archivo: AM10_20230718_092000.WAV, Predicción: Background, Índice: 3
# Archivo: AM10_20230718_092000.WAV, Predicción: Background, Índice: 4
# Archivo: AM10_20230718_092000.WAV, Predicción: Background, Índice: 5
# Archivo: AM10_20230718_092000.WAV, Predicción: Background, Índice: 6
# Archivo: AM10_20230718_092000.WAV, Predicción: Background, Índice: 7
# Archivo: AM10_20230718_092000.WAV, Predicción: Background, Índice: 8
# Archivo: AM10_20230718_092000.WAV, Predicción: Background, Índice: 9
# Archivo: AM10_20230718_092000.WAV, Predicción: Background, Índice: 10
# Archivo: AM10_20230718_092000.WAV, Predicción: Background, Índice: 11
# Archivo: AM10_20230718_092000.WAV, Predicción: Background, Índice: 12
# Archivo: AM10_20230718_092000.WAV, Predicción: Background, Índice: 13
# Archivo: AM10_20230718_092000.WAV, Predicción: Background, Índice: 14
# Archivo: AM10_20230718_092000.WAV, Predicción: Background, Índice: 15
# Archivo: AM10_20230718_092000.WAV, Predicción: Background, Índice: 16
# Archivo: AM10_20230718_092000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 17
# Archivo: AM10_20230718_092000.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 18
# Archivo: AM10_20230718_092000.WAV, Predicción: Saxicola rubicola_European Stonechat, Índice: 19
# Archivo: AM10_20230718_082000.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230718_082000.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM10_20230718_082000.WAV, Predicción: Sturnus, Índice: 2
# Archivo: AM10_20230718_082000.WAV, Predicción: Passer, Índice: 3
# Archivo: AM10_20230718_082000.WAV, Predicción: Sturnus, Índice: 4
# Archivo: AM10_20230718_082000.WAV, Predicción: Background, Índice: 5
# Archivo: AM10_20230718_082000.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM10_20230718_082000.WAV, Predicción: Sturnus, Índice: 7
# Archivo: AM10_20230718_082000.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 8
# Archivo: AM10_20230718_082000.WAV, Predicción: Sturnus, Índice: 9
# Archivo: AM10_20230718_082000.WAV, Predicción: Sturnus, Índice: 10
# Archivo: AM10_20230718_082000.WAV, Predicción: Background, Índice: 11
# Archivo: AM10_20230718_082000.WAV, Predicción: Background, Índice: 12
# Archivo: AM10_20230718_082000.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 13
# Archivo: AM10_20230718_082000.WAV, Predicción: Background, Índice: 14
# Archivo: AM10_20230718_082000.WAV, Predicción: Background, Índice: 15
# Archivo: AM10_20230718_082000.WAV, Predicción: Sturnus, Índice: 16
# Archivo: AM10_20230718_082000.WAV, Predicción: Sturnus, Índice: 17
# Archivo: AM10_20230718_082000.WAV, Predicción: Sturnus, Índice: 18
# Archivo: AM10_20230718_082000.WAV, Predicción: Sturnus, Índice: 19
# Archivo: AM10_20230718_100000.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230718_100000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 1
# Archivo: AM10_20230718_100000.WAV, Predicción: Background, Índice: 2
# Archivo: AM10_20230718_100000.WAV, Predicción: Sylvia, Índice: 3
# Archivo: AM10_20230718_100000.WAV, Predicción: Sturnus, Índice: 4
# Archivo: AM10_20230718_100000.WAV, Predicción: Sturnus, Índice: 5
# Archivo: AM10_20230718_100000.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM10_20230718_100000.WAV, Predicción: Background, Índice: 7
# Archivo: AM10_20230718_100000.WAV, Predicción: Background, Índice: 8
# Archivo: AM10_20230718_100000.WAV, Predicción: Background, Índice: 9
# Archivo: AM10_20230718_100000.WAV, Predicción: Background, Índice: 10
# Archivo: AM10_20230718_100000.WAV, Predicción: Background, Índice: 11
# Archivo: AM10_20230718_100000.WAV, Predicción: Background, Índice: 12
# Archivo: AM10_20230718_100000.WAV, Predicción: Background, Índice: 13
# Archivo: AM10_20230718_100000.WAV, Predicción: Background, Índice: 14
# Archivo: AM10_20230718_100000.WAV, Predicción: Background, Índice: 15
# Archivo: AM10_20230718_100000.WAV, Predicción: Background, Índice: 16
# Archivo: AM10_20230718_100000.WAV, Predicción: Saxicola rubicola_European Stonechat, Índice: 17
# Archivo: AM10_20230718_100000.WAV, Predicción: Background, Índice: 18
# Archivo: AM10_20230718_100000.WAV, Predicción: Background, Índice: 19
# Archivo: AM10_20230718_063000.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM10_20230718_063000.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM10_20230718_063000.WAV, Predicción: Sturnus, Índice: 2
# Archivo: AM10_20230718_063000.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM10_20230718_063000.WAV, Predicción: Sturnus, Índice: 4
# Archivo: AM10_20230718_063000.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 5
# Archivo: AM10_20230718_063000.WAV, Predicción: Background, Índice: 6
# Archivo: AM10_20230718_063000.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 7
# Archivo: AM10_20230718_063000.WAV, Predicción: Passer, Índice: 8
# Archivo: AM10_20230718_063000.WAV, Predicción: Sturnus, Índice: 9
# Archivo: AM10_20230718_063000.WAV, Predicción: Background, Índice: 10
# Archivo: AM10_20230718_063000.WAV, Predicción: Sturnus, Índice: 11
# Archivo: AM10_20230718_063000.WAV, Predicción: Background, Índice: 12
# Archivo: AM10_20230718_063000.WAV, Predicción: Sturnus, Índice: 13
# Archivo: AM10_20230718_063000.WAV, Predicción: Sturnus, Índice: 14
# Archivo: AM10_20230718_063000.WAV, Predicción: Sturnus, Índice: 15
# Archivo: AM10_20230718_063000.WAV, Predicción: Sturnus, Índice: 16
# Archivo: AM10_20230718_063000.WAV, Predicción: Sturnus, Índice: 17
# Archivo: AM10_20230718_063000.WAV, Predicción: Sturnus, Índice: 18
# Archivo: AM10_20230718_063000.WAV, Predicción: Sturnus, Índice: 19
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 0
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 1
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 2
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 3
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 4
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 5
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 6
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 7
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 8
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 9
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 10
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 11
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 12
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 13
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 14
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 15
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 16
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 17
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 18
# Archivo: AM10_20230718_073000.WAV, Predicción: Background, Índice: 19
# Archivo: AM10_20230718_065000.WAV, Predicción: Background, Índice: 0
# Archivo: AM10_20230718_065000.WAV, Predicción: Background, Índice: 1
# Archivo: AM10_20230718_065000.WAV, Predicción: Background, Índice: 2
# Archivo: AM10_20230718_065000.WAV, Predicción: Background, Índice: 3
# Archivo: AM10_20230718_065000.WAV, Predicción: Sturnus, Índice: 4
# Archivo: AM10_20230718_065000.WAV, Predicción: Sturnus, Índice: 5
# Archivo: AM10_20230718_065000.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM10_20230718_065000.WAV, Predicción: Sturnus, Índice: 7
# Archivo: AM10_20230718_065000.WAV, Predicción: Sturnus, Índice: 8
# Archivo: AM10_20230718_065000.WAV, Predicción: Background, Índice: 9
# Archivo: AM10_20230718_065000.WAV, Predicción: Background, Índice: 10
# Archivo: AM10_20230718_065000.WAV, Predicción: Background, Índice: 11
# Archivo: AM10_20230718_065000.WAV, Predicción: Sylvia, Índice: 12
# Archivo: AM10_20230718_065000.WAV, Predicción: Sturnus, Índice: 13
# Archivo: AM10_20230718_065000.WAV, Predicción: Background, Índice: 14
# Archivo: AM10_20230718_065000.WAV, Predicción: Background, Índice: 15
# Archivo: AM10_20230718_065000.WAV, Predicción: Background, Índice: 16
# Archivo: AM10_20230718_065000.WAV, Predicción: Background, Índice: 17
# Archivo: AM10_20230718_065000.WAV, Predicción: Saxicola rubicola_European Stonechat, Índice: 18
# Archivo: AM10_20230718_065000.WAV, Predicción: Sturnus, Índice: 19
# Archivo: AM10_20230718_070000.WAV, Predicción: Background, Índice: 0
# Archivo: AM10_20230718_070000.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 1
# Archivo: AM10_20230718_070000.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 2
# Archivo: AM10_20230718_070000.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 3
# Archivo: AM10_20230718_070000.WAV, Predicción: Sturnus, Índice: 4
# Archivo: AM10_20230718_070000.WAV, Predicción: Background, Índice: 5
# Archivo: AM10_20230718_070000.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM10_20230718_070000.WAV, Predicción: Background, Índice: 7
# Archivo: AM10_20230718_070000.WAV, Predicción: Carduelis carduelis_European Goldfinch, Índice: 8
# Archivo: AM10_20230718_070000.WAV, Predicción: Carduelis carduelis_European Goldfinch, Índice: 9
# Archivo: AM10_20230718_070000.WAV, Predicción: Sturnus, Índice: 10
# Archivo: AM10_20230718_070000.WAV, Predicción: Sturnus, Índice: 11
# Archivo: AM10_20230718_070000.WAV, Predicción: Passer, Índice: 12
# Archivo: AM10_20230718_070000.WAV, Predicción: Sturnus, Índice: 13
# Archivo: AM10_20230718_070000.WAV, Predicción: Background, Índice: 14
# Archivo: AM10_20230718_070000.WAV, Predicción: Sturnus, Índice: 15
# Archivo: AM10_20230718_070000.WAV, Predicción: Passer, Índice: 16
# Archivo: AM10_20230718_070000.WAV, Predicción: Background, Índice: 17
# Archivo: AM10_20230718_070000.WAV, Predicción: Sturnus, Índice: 18
# Archivo: AM10_20230718_070000.WAV, Predicción: Sturnus, Índice: 19
# Archivo: AM10_20230718_093000.WAV, Predicción: Background, Índice: 0
# Archivo: AM10_20230718_093000.WAV, Predicción: Background, Índice: 1
# Archivo: AM10_20230718_093000.WAV, Predicción: Sylvia, Índice: 2
# Archivo: AM10_20230718_093000.WAV, Predicción: Sylvia, Índice: 3
# Archivo: AM10_20230718_093000.WAV, Predicción: Background, Índice: 4
# Archivo: AM10_20230718_093000.WAV, Predicción: Background, Índice: 5
# Archivo: AM10_20230718_093000.WAV, Predicción: Background, Índice: 6
# Archivo: AM10_20230718_093000.WAV, Predicción: Background, Índice: 7
# Archivo: AM10_20230718_093000.WAV, Predicción: Background, Índice: 8
# Archivo: AM10_20230718_093000.WAV, Predicción: Background, Índice: 9
# Archivo: AM10_20230718_093000.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 10
# Archivo: AM10_20230718_093000.WAV, Predicción: Background, Índice: 11
# Archivo: AM10_20230718_093000.WAV, Predicción: Background, Índice: 12
# Archivo: AM10_20230718_093000.WAV, Predicción: Background, Índice: 13
# Archivo: AM10_20230718_093000.WAV, Predicción: Background, Índice: 14
# Archivo: AM10_20230718_093000.WAV, Predicción: Background, Índice: 15
# Archivo: AM10_20230718_093000.WAV, Predicción: Background, Índice: 16
# Archivo: AM10_20230718_093000.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 17
# Archivo: AM10_20230718_093000.WAV, Predicción: Background, Índice: 18
# Archivo: AM10_20230718_093000.WAV, Predicción: Background, Índice: 19
# Archivo: AM10_20230509_063000.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230509_063000.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 1
# Archivo: AM10_20230509_063000.WAV, Predicción: Sturnus, Índice: 2
# Archivo: AM10_20230509_063000.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM10_20230509_063000.WAV, Predicción: Sylvia, Índice: 4
# Archivo: AM10_20230509_063000.WAV, Predicción: Sturnus, Índice: 5
# Archivo: AM10_20230509_063000.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM10_20230509_063000.WAV, Predicción: Sylvia, Índice: 7
# Archivo: AM10_20230509_063000.WAV, Predicción: Sylvia, Índice: 8
# Archivo: AM10_20230509_063000.WAV, Predicción: Background, Índice: 9
# Archivo: AM10_20230509_063000.WAV, Predicción: Background, Índice: 10
# Archivo: AM10_20230509_063000.WAV, Predicción: Sturnus, Índice: 11
# Archivo: AM10_20230509_063000.WAV, Predicción: Sylvia, Índice: 12
# Archivo: AM10_20230509_063000.WAV, Predicción: Background, Índice: 13
# Archivo: AM10_20230509_063000.WAV, Predicción: Sturnus, Índice: 14
# Archivo: AM10_20230509_063000.WAV, Predicción: Sturnus, Índice: 15
# Archivo: AM10_20230509_063000.WAV, Predicción: Passer, Índice: 16
# Archivo: AM10_20230509_063000.WAV, Predicción: Sturnus, Índice: 17
# Archivo: AM10_20230509_063000.WAV, Predicción: Sturnus, Índice: 18
# Archivo: AM10_20230509_063000.WAV, Predicción: Sturnus, Índice: 19
# Archivo: AM10_20230509_070000.WAV, Predicción: Background, Índice: 0
# Archivo: AM10_20230509_070000.WAV, Predicción: Background, Índice: 1
# Archivo: AM10_20230509_070000.WAV, Predicción: Background, Índice: 2
# Archivo: AM10_20230509_070000.WAV, Predicción: Background, Índice: 3
# Archivo: AM10_20230509_070000.WAV, Predicción: Background, Índice: 4
# Archivo: AM10_20230509_070000.WAV, Predicción: Sturnus, Índice: 5
# Archivo: AM10_20230509_070000.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM10_20230509_070000.WAV, Predicción: Sturnus, Índice: 7
# Archivo: AM10_20230509_070000.WAV, Predicción: Sturnus, Índice: 8
# Archivo: AM10_20230509_070000.WAV, Predicción: Sturnus, Índice: 9
# Archivo: AM10_20230509_070000.WAV, Predicción: Sturnus, Índice: 10
# Archivo: AM10_20230509_070000.WAV, Predicción: Sturnus, Índice: 11
# Archivo: AM10_20230509_070000.WAV, Predicción: Sturnus, Índice: 12
# Archivo: AM10_20230509_070000.WAV, Predicción: Background, Índice: 13
# Archivo: AM10_20230509_070000.WAV, Predicción: Background, Índice: 14
# Archivo: AM10_20230509_070000.WAV, Predicción: Background, Índice: 15
# Archivo: AM10_20230509_070000.WAV, Predicción: Background, Índice: 16
# Archivo: AM10_20230509_070000.WAV, Predicción: Background, Índice: 17
# Archivo: AM10_20230509_070000.WAV, Predicción: Sturnus, Índice: 18
# Archivo: AM10_20230509_070000.WAV, Predicción: Background, Índice: 19
# Archivo: AM10_20230509_090000.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230509_090000.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM10_20230509_090000.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 2
# ...
# Archivo: AM11_20230530_095000.WAV, Predicción: Sturnus, Índice: 8
# Archivo: AM11_20230530_095000.WAV, Predicción: Sturnus, Índice: 9
# Archivo: AM11_20230530_095000.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 10
# Archivo: AM11_20230530_095000.WAV, Predicción: Background, Índice: 11
# Archivo: AM11_20230530_095000.WAV, Predicción: Background, Índice: 12
# Archivo: AM11_20230530_095000.WAV, Predicción: Background, Índice: 13
# Archivo: AM11_20230530_095000.WAV, Predicción: Sylvia, Índice: 14
# Archivo: AM11_20230530_095000.WAV, Predicción: Background, Índice: 15
# Archivo: AM11_20230530_095000.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 16
# Archivo: AM11_20230530_095000.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 17
# Archivo: AM11_20230530_095000.WAV, Predicción: Sturnus, Índice: 18
# Archivo: AM11_20230530_095000.WAV, Predicción: Sturnus, Índice: 19
# Archivo: AM11_20230530_080000.WAV, Predicción: Background, Índice: 0
# Archivo: AM11_20230530_080000.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM11_20230530_080000.WAV, Predicción: Background, Índice: 2
# Archivo: AM11_20230530_080000.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM11_20230530_080000.WAV, Predicción: Background, Índice: 4
# Archivo: AM11_20230530_080000.WAV, Predicción: Background, Índice: 5
# Archivo: AM11_20230530_080000.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM11_20230530_080000.WAV, Predicción: Sturnus, Índice: 7
# Archivo: AM11_20230530_080000.WAV, Predicción: Sturnus, Índice: 8
# Archivo: AM11_20230530_080000.WAV, Predicción: Sturnus, Índice: 9
# Archivo: AM11_20230530_080000.WAV, Predicción: Sturnus, Índice: 10
# Archivo: AM11_20230530_080000.WAV, Predicción: Sylvia, Índice: 11
# Archivo: AM11_20230530_080000.WAV, Predicción: Sturnus, Índice: 12
# Archivo: AM11_20230530_080000.WAV, Predicción: Sturnus, Índice: 13
# Archivo: AM11_20230530_080000.WAV, Predicción: Background, Índice: 14
# Archivo: AM11_20230530_080000.WAV, Predicción: Sturnus, Índice: 15
# Archivo: AM11_20230530_080000.WAV, Predicción: Sturnus, Índice: 16
# Archivo: AM11_20230530_080000.WAV, Predicción: Sturnus, Índice: 17
# Archivo: AM11_20230530_080000.WAV, Predicción: Background, Índice: 18
# Archivo: AM11_20230530_080000.WAV, Predicción: Sturnus, Índice: 19
# Archivo: AM11_20230530_074000.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM11_20230530_074000.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 1
# Archivo: AM11_20230530_074000.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 2
# Archivo: AM11_20230530_074000.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM11_20230530_074000.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 4
# Archivo: AM11_20230530_074000.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 5
# Archivo: AM11_20230530_074000.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM11_20230530_074000.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 7
# Archivo: AM11_20230530_074000.WAV, Predicción: Sturnus, Índice: 8
# Archivo: AM11_20230530_074000.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 9
# Archivo: AM11_20230530_074000.WAV, Predicción: Sturnus, Índice: 10
# Archivo: AM11_20230530_074000.WAV, Predicción: Sturnus, Índice: 11
# Archivo: AM11_20230530_074000.WAV, Predicción: Sturnus, Índice: 12
# Archivo: AM11_20230530_074000.WAV, Predicción: Sturnus, Índice: 13
# Archivo: AM11_20230530_074000.WAV, Predicción: Sturnus, Índice: 14
# Archivo: AM11_20230530_074000.WAV, Predicción: Sturnus, Índice: 15
# Archivo: AM11_20230530_074000.WAV, Predicción: Sturnus, Índice: 16
# Archivo: AM11_20230530_074000.WAV, Predicción: Background, Índice: 17
# Archivo: AM11_20230530_074000.WAV, Predicción: Background, Índice: 18
# Archivo: AM11_20230530_074000.WAV, Predicción: Sturnus, Índice: 19
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 0
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 1
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 2
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 3
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 4
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 5
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 6
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 7
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 8
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 9
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 10
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 11
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 12
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 13
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 14
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 15
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 16
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 17
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 18
# Archivo: AM11_20230303_060000.WAV, Predicción: Background, Índice: 19
# Archivo: AM11_20230303_063000.WAV, Predicción: Background, Índice: 0
# Archivo: AM11_20230303_063000.WAV, Predicción: Background, Índice: 1
# Archivo: AM11_20230303_063000.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 2
# Archivo: AM11_20230303_063000.WAV, Predicción: Background, Índice: 3
# Archivo: AM11_20230303_063000.WAV, Predicción: Sturnus, Índice: 4
# Archivo: AM11_20230303_063000.WAV, Predicción: Saxicola rubicola_European Stonechat, Índice: 5
# Archivo: AM11_20230303_063000.WAV, Predicción: Background, Índice: 6
# Archivo: AM11_20230303_063000.WAV, Predicción: Background, Índice: 7
# Archivo: AM11_20230303_063000.WAV, Predicción: Background, Índice: 8
# Archivo: AM11_20230303_063000.WAV, Predicción: Background, Índice: 9
# Archivo: AM11_20230303_063000.WAV, Predicción: Background, Índice: 10
# Archivo: AM11_20230303_063000.WAV, Predicción: Background, Índice: 11
# Archivo: AM11_20230303_063000.WAV, Predicción: Background, Índice: 12
# Archivo: AM11_20230303_063000.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 13
# Archivo: AM11_20230303_063000.WAV, Predicción: Background, Índice: 14
# Archivo: AM11_20230303_063000.WAV, Predicción: Background, Índice: 15
# Archivo: AM11_20230303_063000.WAV, Predicción: Background, Índice: 16
# Archivo: AM11_20230303_063000.WAV, Predicción: Background, Índice: 17
# Archivo: AM11_20230303_063000.WAV, Predicción: Background, Índice: 18
# Archivo: AM11_20230303_063000.WAV, Predicción: Background, Índice: 19
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 2
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 4
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 5
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 7
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 8
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 9
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 10
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 11
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 12
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 13
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 14
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 15
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 16
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 17
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 18
# Archivo: AM8_20230304_070000.WAV, Predicción: Sturnus, Índice: 19
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 2
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 4
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 5
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 7
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 8
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 9
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 10
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 11
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 12
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 13
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 14
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 15
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 16
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 17
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 18
# Archivo: AM8_20230304_093000.WAV, Predicción: Sturnus, Índice: 19
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 2
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 4
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 5
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 7
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 8
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 9
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 10
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 11
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 12
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 13
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 14
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 15
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 16
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 17
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 18
# Archivo: AM8_20230304_100000.WAV, Predicción: Sturnus, Índice: 19
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 2
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 4
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 5
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 7
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 8
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 9
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 10
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 11
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 12
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 13
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 14
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 15
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 16
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 17
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 18
# Archivo: AM8_20230523_064000.WAV, Predicción: Sturnus, Índice: 19
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 2
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 4
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 5
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 7
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 8
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 9
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 10
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 11
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 12
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 13
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 14
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 15
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 16
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 17
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 18
# Archivo: AM8_20230523_101000.WAV, Predicción: Sturnus, Índice: 19
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 0
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 1
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 2
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 3
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 4
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 5
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 6
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 7
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 8
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 9
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 10
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 11
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 12
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 13
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 14
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 15
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 16
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 17
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 18
# Archivo: AM4_20230531_092000.WAV, Predicción: Background, Índice: 19
# Archivo: AM4_20230531_110000.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 0
# Archivo: AM4_20230531_110000.WAV, Predicción: Background, Índice: 1
# Archivo: AM4_20230531_110000.WAV, Predicción: Background, Índice: 2
# Archivo: AM4_20230531_110000.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM4_20230531_110000.WAV, Predicción: Sturnus, Índice: 4
# Archivo: AM4_20230531_110000.WAV, Predicción: Background, Índice: 5
# Archivo: AM4_20230531_110000.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM4_20230531_110000.WAV, Predicción: Sylvia, Índice: 7
# Archivo: AM4_20230531_110000.WAV, Predicción: Background, Índice: 8
# Archivo: AM4_20230531_110000.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 9
# Archivo: AM4_20230531_110000.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 10
# Archivo: AM4_20230531_110000.WAV, Predicción: Background, Índice: 11
# Archivo: AM4_20230531_110000.WAV, Predicción: Background, Índice: 12
# Archivo: AM4_20230531_110000.WAV, Predicción: Background, Índice: 13
# Archivo: AM4_20230531_110000.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 14
# Archivo: AM4_20230531_110000.WAV, Predicción: Background, Índice: 15
# Archivo: AM4_20230531_110000.WAV, Predicción: Background, Índice: 16
# Archivo: AM4_20230531_110000.WAV, Predicción: Background, Índice: 17
# Archivo: AM4_20230531_110000.WAV, Predicción: Background, Índice: 18
# Archivo: AM4_20230531_110000.WAV, Predicción: Background, Índice: 19

# %%
import os

# Save predictions in a folder named "predictions" for each prediction, one file with the name of the audio and the prediction
predictions_folder = "../../RandomForest/predictions/test"
os.makedirs(predictions_folder, exist_ok=True)

start_s = 0
end_s = 3.0
current_file_name = None

# sort filenames and predictions by filename alphabetically
test_file_names, test_predictions, test_files_idx = zip(*sorted(zip(test_file_names, test_predictions, test_files_idx)))

for file_name, pred, idx in zip(test_file_names, test_predictions, test_files_idx):
    filename = file_name.replace(".WAV", ".BirdNET.results").replace(".wav", ".BirdNET.results")
    file_path = os.path.join(predictions_folder, filename + ".csv")

    # Reset time if a new file starts
    if current_file_name != filename:
        current_file_name = filename
        # write_header = True  # Flag to write header only once
        with open(file_path, "a") as f:
            f.write("Start (s),End (s),Scientific name,Common name,Confidence\n")

    start_s = 0 + 3.0 * idx
    end_s = 3.0 + 3.0 * idx

    if end_s > 60:
        print(f"Skipping prediction for {file_name}: {pred}, {end_s}")

    # Only write predictions if not "Background"
    if pred != "Background":
        # print(f"Saving prediction for {file_name}: {pred}")
        
        # Extract scientific and common name
        if "_" in pred:
            scientific_name, common_name = pred.split("_", 1)
        else:
            scientific_name = pred
            common_name = pred

        # Append to the file
        with open(file_path, "a") as f:
            f.write(f"{start_s},{end_s},{scientific_name},{common_name},1\n")

print("Predictions saved successfully.")
# Out:
# Predictions saved successfully.

# %%
# Predecir etiquetas de los audios de prueba
bsd_test_predictions = rf_best_model.predict(bsd_test_embeddings.reshape(bsd_test_embeddings.shape[0], -1))

# Decodificar las etiquetas predichas
bsd_test_predictions = label_encoder.inverse_transform(bsd_test_predictions)

# Mostrar las predicciones para cada archivo
for file_name, pred, idx in zip(bsd_test_file_names, bsd_test_predictions, bsd_test_files_idx):
    print(f"Archivo: {file_name}, Predicción: {pred}, Índice: {idx}")
# Out:
# Archivo: AM1_20230510_083000_28.74_30.30_0.40.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM10_20230523_070000_0.00_1.70_0.61.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM1_20230512_090000_20.60_22.01_0.80.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230523_070000_58.76_59.99_0.22.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM8_20230523_064000_52.48_53.54_0.17.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230512_090000_31.75_33.38_0.20.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230512_090000_40.38_42.01_0.50.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM8_20230523_101000_44.08_44.68_0.22.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM10_20230718_070000_23.95_24.99_0.28.WAV, Predicción: Carduelis carduelis_European Goldfinch, Índice: 0
# Archivo: AM10_20230523_063000_45.84_47.01_0.18.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230511_090000_6.04_7.29_0.17.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230510_083000_57.33_58.47_0.41.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230511_093000_54.20_56.24_0.78.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230512_090000_45.49_46.24_0.26.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230511_103000_0.21_2.26_0.23.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230523_063000_2.42_3.88_0.18.WAV, Predicción: Background, Índice: 0
# Archivo: AM8_20230523_064000_0.00_0.94_0.20.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM1_20230512_083000_22.18_23.36_0.35.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM8_20230523_064000_33.94_35.21_0.36.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM11_20230530_063000_7.81_9.05_0.15.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230718_063000_24.86_26.11_0.23.WAV, Predicción: Carduelis carduelis_European Goldfinch, Índice: 0
# Archivo: AM10_20230718_082000_48.48_49.72_0.31.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230718_074000_37.32_38.83_0.18.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230512_090000_56.11_57.33_0.30.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230718_082000_50.36_52.54_0.19.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM11_20230303_063000_38.97_40.61_0.16.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM8_20230304_100000_40.93_44.27_0.35.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230523_064000_16.16_18.02_0.23.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230511_063000_53.42_56.47_0.20.WAV, Predicción: Background, Índice: 0
# Archivo: AM8_20230304_070000_15.68_17.00_0.16.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230523_063000_51.25_53.21_0.25.WAV, Predicción: Background, Índice: 0
# Archivo: AM8_20230523_101000_52.09_54.57_0.20.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230523_070000_28.92_30.77_0.86.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM11_20230303_063000_9.96_11.21_0.31.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230512_090000_25.76_27.45_0.60.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230718_071000_26.90_29.07_0.20.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM8_20230523_101000_55.81_57.66_0.57.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230718_082000_11.19_13.50_0.21.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM10_20230718_065000_0.09_2.63_0.54.WAV, Predicción: Background, Índice: 0
# Archivo: AM11_20230530_074000_0.25_2.01_0.27.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM10_20230718_063000_15.89_17.20_0.21.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230523_070000_3.27_4.45_0.29.WAV, Predicción: Background, Índice: 0
# Archivo: AM10_20230718_071000_42.65_44.68_0.37.WAV, Predicción: Carduelis carduelis_European Goldfinch, Índice: 0
# Archivo: AM1_20230510_083000_46.59_47.44_0.30.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM10_20230523_070000_24.87_26.22_0.27.WAV, Predicción: Carduelis carduelis_European Goldfinch, Índice: 0
# Archivo: AM1_20230512_103000_47.98_49.25_0.38.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM15_20230330_070000_0.00_0.92_0.34.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM11_20230303_060000_2.32_3.88_0.42.WAV, Predicción: Saxicola rubicola_European Stonechat, Índice: 0
# Archivo: AM8_20230304_070000_17.29_31.22_0.27.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230304_070000_17.29_31.22_0.27.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM8_20230304_070000_17.29_31.22_0.27.WAV, Predicción: Sturnus, Índice: 2
# Archivo: AM8_20230304_070000_17.29_31.22_0.27.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM10_20230718_071000_38.06_39.53_0.51.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230509_090000_49.04_50.29_0.18.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM10_20230509_090000_1.79_3.22_0.19.WAV, Predicción: Carduelis carduelis_European Goldfinch, Índice: 0
# Archivo: AM1_20230511_090000_13.64_14.99_0.43.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM8_20230304_100000_31.78_35.05_0.22.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM11_20230303_063000_12.89_17.71_0.47.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230511_090000_1.84_3.23_0.20.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM8_20230304_093000_34.96_42.66_0.26.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230304_093000_34.96_42.66_0.26.WAV, Predicción: Passer, Índice: 1
# Archivo: AM8_20230304_070000_0.09_1.27_0.18.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230523_070000_33.85_35.19_0.40.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM1_20230511_060000_1.71_2.62_0.29.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM15_20230330_070000_43.87_44.78_0.17.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM10_20230718_074000_16.19_17.54_0.33.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230515_083000_16.32_17.96_0.23.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM1_20230514_103000_20.63_23.06_0.76.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230514_110000_53.62_58.15_0.28.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230510_083000_17.69_21.92_0.44.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM4_20230531_092000_0.02_1.76_0.60.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230523_063000_50.13_51.67_0.55.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM15_20230330_070000_33.39_34.15_0.23.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 0
# Archivo: AM10_20230523_070000_44.18_45.76_0.72.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM10_20230718_082000_21.55_23.74_0.23.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM1_20230511_103000_40.72_42.48_0.24.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230718_074000_20.17_23.48_0.46.WAV, Predicción: Background, Índice: 0
# Archivo: AM11_20230530_065000_16.24_20.75_0.19.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230510_080000_44.94_46.35_0.27.WAV, Predicción: Background, Índice: 0
# Archivo: AM10_20230718_070000_36.88_38.18_0.17.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230718_071000_19.90_20.98_0.18.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM15_20230330_063000_26.45_28.41_0.38.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM8_20230523_064000_18.50_20.27_0.28.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230718_070000_53.43_56.01_0.17.WAV, Predicción: Passer, Índice: 0
# Archivo: AM8_20230523_101000_37.60_40.74_0.26.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230511_060000_38.88_40.49_0.56.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM11_20230303_060000_9.42_10.12_0.22.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM10_20230718_063000_7.93_9.56_0.53.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230511_060000_49.50_50.66_0.62.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM8_20230523_064000_55.83_57.20_0.17.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230304_100000_18.28_20.71_0.39.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230512_090000_4.93_6.61_0.67.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230512_103000_45.50_46.25_0.30.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230523_070000_16.09_17.23_0.32.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM1_20230511_060000_34.14_35.33_0.60.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM1_20230515_090000_46.39_47.93_0.58.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230509_090000_36.93_38.23_0.15.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM10_20230718_071000_32.27_34.92_0.20.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230512_103000_55.95_57.04_0.19.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM8_20230523_101000_0.03_1.64_0.37.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM8_20230304_100000_18.92_36.11_0.39.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230304_100000_18.92_36.11_0.39.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM8_20230304_100000_18.92_36.11_0.39.WAV, Predicción: Sturnus, Índice: 2
# Archivo: AM8_20230304_100000_18.92_36.11_0.39.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM8_20230304_100000_18.92_36.11_0.39.WAV, Predicción: Sturnus, Índice: 4
# Archivo: AM10_20230718_063000_38.09_39.42_0.23.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM10_20230523_070000_18.11_19.79_0.15.WAV, Predicción: Background, Índice: 0
# Archivo: AM10_20230523_063000_53.93_55.37_0.45.WAV, Predicción: Background, Índice: 0
# Archivo: AM8_20230304_100000_38.25_40.21_0.39.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230523_101000_29.87_31.81_0.46.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230523_064000_0.02_30.56_0.55.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230523_064000_0.02_30.56_0.55.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM8_20230523_064000_0.02_30.56_0.55.WAV, Predicción: Sturnus, Índice: 2
# Archivo: AM8_20230523_064000_0.02_30.56_0.55.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM8_20230523_064000_0.02_30.56_0.55.WAV, Predicción: Sturnus, Índice: 4
# Archivo: AM8_20230523_064000_0.02_30.56_0.55.WAV, Predicción: Sturnus, Índice: 5
# Archivo: AM8_20230523_064000_0.02_30.56_0.55.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM8_20230523_064000_0.02_30.56_0.55.WAV, Predicción: Sturnus, Índice: 7
# Archivo: AM8_20230523_064000_0.02_30.56_0.55.WAV, Predicción: Sturnus, Índice: 8
# Archivo: AM8_20230523_064000_0.02_30.56_0.55.WAV, Predicción: Sturnus, Índice: 9
# Archivo: AM10_20230718_082000_57.62_58.57_0.29.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230304_093000_3.38_60.00_0.54.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230304_093000_3.38_60.00_0.54.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM8_20230304_093000_3.38_60.00_0.54.WAV, Predicción: Sturnus, Índice: 2
# Archivo: AM8_20230304_093000_3.38_60.00_0.54.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM8_20230304_093000_3.38_60.00_0.54.WAV, Predicción: Sturnus, Índice: 4
# Archivo: AM8_20230304_093000_3.38_60.00_0.54.WAV, Predicción: Sturnus, Índice: 5
# Archivo: AM8_20230304_093000_3.38_60.00_0.54.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM8_20230304_093000_3.38_60.00_0.54.WAV, Predicción: Sturnus, Índice: 7
# Archivo: AM8_20230304_093000_3.38_60.00_0.54.WAV, Predicción: Sturnus, Índice: 8
# Archivo: AM8_20230304_093000_3.38_60.00_0.54.WAV, Predicción: Sturnus, Índice: 9
# Archivo: AM8_20230304_093000_3.38_60.00_0.54.WAV, Predicción: Sturnus, Índice: 10
# Archivo: AM8_20230304_093000_3.38_60.00_0.54.WAV, Predicción: Sturnus, Índice: 11
# Archivo: AM8_20230304_093000_3.38_60.00_0.54.WAV, Predicción: Sturnus, Índice: 12
# Archivo: AM8_20230304_093000_3.38_60.00_0.54.WAV, Predicción: Sturnus, Índice: 13
# Archivo: AM8_20230304_093000_3.38_60.00_0.54.WAV, Predicción: Sturnus, Índice: 14
# Archivo: AM8_20230304_093000_3.38_60.00_0.54.WAV, Predicción: Sturnus, Índice: 15
# Archivo: AM8_20230304_093000_3.38_60.00_0.54.WAV, Predicción: Sturnus, Índice: 16
# Archivo: AM8_20230304_093000_3.38_60.00_0.54.WAV, Predicción: Sturnus, Índice: 17
# Archivo: AM8_20230304_093000_31.77_35.04_0.24.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM11_20230530_081000_31.35_35.46_0.38.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230718_070000_58.09_59.97_0.16.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230511_093000_48.60_50.94_0.34.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230511_060000_5.74_8.88_0.48.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM8_20230523_101000_9.04_10.52_0.16.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM8_20230304_100000_2.67_16.50_0.42.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230304_100000_2.67_16.50_0.42.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM8_20230304_100000_2.67_16.50_0.42.WAV, Predicción: Sturnus, Índice: 2
# Archivo: AM8_20230304_100000_2.67_16.50_0.42.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM15_20230330_063000_7.96_9.52_0.20.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM8_20230304_070000_26.88_28.52_0.36.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230512_103000_39.53_40.94_0.56.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230718_073000_50.85_52.00_0.15.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230515_083000_30.08_32.23_0.19.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230514_103000_16.74_17.66_0.35.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230718_063000_34.42_35.58_0.23.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM1_20230514_103000_35.14_36.67_0.34.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM1_20230514_103000_3.63_5.94_0.69.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM10_20230509_090000_13.00_14.38_0.20.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 0
# Archivo: AM1_20230515_083000_48.85_50.28_0.22.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230718_074000_2.42_6.26_0.42.WAV, Predicción: Passer, Índice: 0
# Archivo: AM8_20230523_064000_38.94_40.12_0.17.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230515_090000_28.16_29.81_0.25.WAV, Predicción: Background, Índice: 0
# Archivo: AM15_20230330_070000_15.88_17.07_0.22.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM1_20230512_103000_12.80_14.21_0.19.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM11_20230303_063000_26.91_28.60_0.38.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230523_063000_18.33_19.56_0.62.WAV, Predicción: Background, Índice: 0
# Archivo: AM15_20230330_063000_43.40_44.90_0.17.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230523_070000_57.42_58.56_0.26.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 0
# Archivo: AM1_20230515_083000_28.66_29.96_0.29.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230718_071000_36.31_37.29_0.15.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230718_063000_45.27_47.34_0.48.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM15_20230330_070000_24.23_26.18_0.16.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230510_083000_50.67_52.82_0.60.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM8_20230304_093000_19.59_20.99_0.21.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM11_20230530_074000_11.27_13.21_0.32.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM10_20230718_100000_46.08_47.77_0.26.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM15_20230330_063000_57.23_58.46_0.17.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230512_090000_48.04_50.31_0.76.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM15_20230330_063000_49.35_50.92_0.26.WAV, Predicción: Saxicola rubicola_European Stonechat, Índice: 0
# Archivo: AM8_20230304_100000_28.09_29.01_0.16.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230509_090000_23.78_25.38_0.16.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230523_063000_0.00_0.88_0.17.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 2
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 4
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 5
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 6
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 7
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 8
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 9
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 10
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 11
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 12
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 13
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 14
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 15
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 16
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 17
# Archivo: AM11_20230530_071000_0.57_60.00_0.64.WAV, Predicción: Sturnus, Índice: 18
# Archivo: AM8_20230304_100000_55.99_60.00_0.42.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230718_101000_16.35_19.44_0.43.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230718_074000_13.74_15.63_0.16.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM8_20230523_064000_40.79_42.24_0.17.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230523_101000_32.68_34.48_0.33.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM8_20230523_064000_46.73_48.42_0.21.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230511_063000_20.03_20.76_0.19.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM1_20230514_103000_30.02_31.14_0.71.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM8_20230304_070000_46.04_60.00_0.44.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230304_070000_46.04_60.00_0.44.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM8_20230304_070000_46.04_60.00_0.44.WAV, Predicción: Sturnus, Índice: 2
# Archivo: AM8_20230304_070000_46.04_60.00_0.44.WAV, Predicción: Sturnus, Índice: 3
# Archivo: AM8_20230523_064000_42.93_44.16_0.33.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230718_070000_49.34_50.55_0.17.WAV, Predicción: Carduelis carduelis_European Goldfinch, Índice: 0
# Archivo: AM10_20230523_063000_24.40_25.89_0.73.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM10_20230718_070000_0.04_2.47_0.22.WAV, Predicción: Background, Índice: 0
# Archivo: AM10_20230523_070000_55.72_56.41_0.28.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM1_20230515_090000_52.70_54.24_0.16.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM11_20230530_074000_28.15_30.07_0.53.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM10_20230523_070000_26.66_28.03_0.16.WAV, Predicción: Background, Índice: 0
# Archivo: AM10_20230718_074000_30.44_32.37_0.37.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230509_090000_31.95_32.46_0.22.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM10_20230718_082000_30.77_33.02_0.25.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230523_101000_18.88_21.69_0.17.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM10_20230718_074000_0.01_2.46_0.19.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 0
# Archivo: AM8_20230304_070000_2.65_6.48_0.25.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230523_064000_27.83_29.24_0.15.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM11_20230530_065000_0.00_7.59_0.44.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM11_20230530_065000_0.00_7.59_0.44.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM1_20230514_103000_13.27_15.72_0.77.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM8_20230523_101000_41.08_43.63_0.20.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230523_101000_58.40_60.00_0.29.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM1_20230511_093000_32.97_35.07_0.44.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230511_093000_59.07_59.98_0.18.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230510_083000_15.04_15.99_0.16.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM11_20230530_063000_0.00_0.96_0.36.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM8_20230523_064000_25.49_27.06_0.33.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230523_064000_30.84_32.23_0.16.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230718_074000_42.88_46.52_0.36.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230511_060000_51.39_53.09_0.31.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM10_20230718_071000_0.05_1.90_0.28.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 0
# Archivo: AM10_20230523_070000_11.70_13.43_0.75.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM10_20230718_070000_25.62_29.09_0.21.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230509_063000_21.77_23.40_0.18.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230511_090000_28.08_29.51_0.21.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230510_083000_35.53_36.89_0.16.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM8_20230523_101000_13.74_15.07_0.21.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM1_20230512_103000_35.79_36.91_0.63.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230509_090000_19.78_20.83_0.16.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM10_20230718_071000_56.82_57.83_0.15.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM10_20230509_090000_5.47_6.95_0.30.WAV, Predicción: Saxicola rubicola_European Stonechat, Índice: 0
# Archivo: AM1_20230511_060000_44.77_47.09_0.52.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM8_20230304_093000_46.17_49.91_0.28.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230511_103000_8.11_10.22_0.42.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM10_20230509_090000_52.85_53.90_0.28.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM1_20230511_060000_14.87_16.63_0.51.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM8_20230304_093000_50.07_59.94_0.36.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230304_093000_50.07_59.94_0.36.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM8_20230304_093000_50.07_59.94_0.36.WAV, Predicción: Sturnus, Índice: 2
# Archivo: AM1_20230512_103000_29.87_32.35_0.75.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230718_070000_44.86_48.26_0.17.WAV, Predicción: Carduelis carduelis_European Goldfinch, Índice: 0
# Archivo: AM8_20230304_093000_26.75_28.70_0.34.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230512_090000_0.01_1.44_0.64.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM8_20230304_093000_0.20_5.52_0.71.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230523_063000_5.74_6.93_0.30.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM8_20230304_100000_0.04_1.42_0.17.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230523_063000_30.41_31.32_0.23.WAV, Predicción: Background, Índice: 0
# Archivo: AM10_20230523_063000_11.74_13.34_0.40.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM11_20230530_102000_0.00_3.13_0.15.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230718_093000_49.88_51.67_0.59.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230511_060000_20.51_23.57_0.75.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM1_20230511_060000_54.90_56.22_0.24.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM8_20230523_101000_44.47_46.65_0.54.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230512_090000_15.62_16.55_0.21.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230511_093000_44.08_45.88_0.69.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230718_093000_52.39_54.12_0.41.WAV, Predicción: Cisticola juncidis_Zitting Cisticola, Índice: 0
# Archivo: AM10_20230718_070000_41.90_43.07_0.16.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230512_103000_22.46_24.71_0.54.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230718_065000_23.88_26.39_0.15.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230718_063000_1.39_2.78_0.36.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM15_20230330_063000_31.49_33.53_0.50.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM8_20230523_064000_20.87_23.25_0.26.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM15_20230330_070000_40.55_42.50_0.16.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM11_20230303_063000_41.74_43.73_0.69.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230514_103000_9.53_10.70_0.39.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230512_103000_0.02_1.51_0.31.WAV, Predicción: Background, Índice: 0
# Archivo: AM8_20230304_100000_52.93_54.87_0.25.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230718_071000_7.42_8.42_0.51.WAV, Predicción: Background, Índice: 0
# Archivo: AM4_20230531_092000_39.50_41.28_0.47.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230515_090000_39.02_40.61_0.23.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230510_083000_24.22_26.08_0.52.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM8_20230523_101000_0.00_10.30_0.70.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM8_20230523_101000_0.00_10.30_0.70.WAV, Predicción: Sturnus, Índice: 1
# Archivo: AM8_20230523_101000_0.00_10.30_0.70.WAV, Predicción: Sturnus, Índice: 2
# Archivo: AM10_20230718_070000_31.50_32.92_0.32.WAV, Predicción: Carduelis carduelis_European Goldfinch, Índice: 0
# Archivo: AM10_20230523_063000_32.95_34.51_0.79.WAV, Predicción: Background, Índice: 0
# Archivo: AM1_20230511_093000_38.74_40.54_0.56.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM11_20230303_063000_51.01_52.18_0.25.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM1_20230511_103000_49.06_50.60_0.51.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM1_20230511_060000_0.00_0.84_0.26.WAV, Predicción: Saxicola rubicola_European Stonechat, Índice: 0
# Archivo: AM10_20230718_074000_40.89_42.80_0.22.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM8_20230304_093000_9.10_11.13_0.33.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM11_20230530_071000_12.23_14.71_0.29.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230511_060000_29.40_30.87_0.70.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM10_20230523_070000_21.14_24.16_0.15.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230512_090000_10.85_12.12_0.21.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM8_20230523_101000_36.26_37.73_0.15.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM15_20230330_063000_44.53_46.36_0.49.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM8_20230523_064000_36.34_37.92_0.18.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM11_20230303_063000_46.51_47.53_0.19.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM10_20230718_082000_39.71_42.14_0.25.WAV, Predicción: Saxicola rubicola_European Stonechat, Índice: 0
# Archivo: AM10_20230718_063000_10.48_13.40_0.15.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM1_20230514_103000_24.20_25.90_0.32.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230509_090000_58.66_59.97_0.19.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM4_20230531_110000_19.58_21.68_0.59.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0
# Archivo: AM11_20230530_074000_5.66_7.44_0.57.WAV, Predicción: Emberiza calandra_Corn Bunting, Índice: 0
# Archivo: AM8_20230304_070000_29.47_34.35_0.39.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230523_070000_40.11_41.38_0.39.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM11_20230530_071000_0.00_3.84_0.18.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230718_082000_2.18_5.68_0.15.WAV, Predicción: Sturnus, Índice: 0
# Archivo: AM10_20230718_071000_30.95_32.14_0.18.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM1_20230512_103000_2.69_4.92_0.45.WAV, Predicción: Sylvia, Índice: 0
# Archivo: AM10_20230718_100000_34.65_39.31_0.35.WAV, Predicción: Background, Índice: 0
# Archivo: AM10_20230523_070000_6.88_8.21_0.36.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM10_20230523_070000_20.48_21.85_0.40.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM10_20230509_090000_0.01_1.03_0.16.WAV, Predicción: Luscinia megarhynchos_Common Nightingale, Índice: 0
# Archivo: AM11_20230303_063000_31.67_32.76_0.15.WAV, Predicción: Galerida theklae_Thekla's Lark, Índice: 0

# %%
import os

# Save predictions in a folder named "predictions" for each prediction, one file with the name of the audio and the prediction
predictions_folder = "../../RandomForest/predictions/BirdSongDetectorTest"
os.makedirs(predictions_folder, exist_ok=True)

start_s = 0
end_s = 3.0
current_file_name = None

# sort filenames and predictions by filename alphabetically
bsd_test_file_names, bsd_test_predictions, bsd_test_files_idx = zip(*sorted(zip(bsd_test_file_names, bsd_test_predictions, bsd_test_files_idx)))

for file_name, pred, idx in zip(bsd_test_file_names, bsd_test_predictions, bsd_test_files_idx):
    filename = file_name.replace(".WAV", ".BirdNET.results").replace(".wav", ".BirdNET.results")
    file_path = os.path.join(predictions_folder, filename + ".csv")

    # Reset time if a new file starts
    if current_file_name != filename:
        current_file_name = filename
        # write_header = True  # Flag to write header only once
        with open(file_path, "a") as f:
            f.write("Start (s),End (s),Scientific name,Common name,Confidence\n")

    start_s = 0 + 3.0 * idx
    end_s = 3.0 + 3.0 * idx

    if end_s > 60:
        print(f"Skipping prediction for {file_name}: {pred}, {end_s}")

    # Only write predictions if not "Background"
    if pred != "Background":
        # print(f"Saving prediction for {file_name}: {pred}")
        
        # Extract scientific and common name
        if "_" in pred:
            scientific_name, common_name = pred.split("_", 1)
        else:
            scientific_name = pred
            common_name = pred

        # Append to the file
        with open(file_path, "a") as f:
            f.write(f"{start_s},{end_s},{scientific_name},{common_name},1\n")

print("Predictions saved successfully.")
# Out:
# Predictions saved successfully.

# %%
# Save predictions in a folder named "predictions" for each prediction, one file with the name of the audio and the prediction, start_time = 0 and end_time = 3
predictions_folder = "BirdSongDetectorRGBPredictions"
os.makedirs(predictions_folder, exist_ok=True)

for file_name, pred in zip(test_file_names, test_predictions):
    filename = file_name.replace("WAV", "BirdNET.results")
    with open(os.path.join(predictions_folder, filename + ".csv"), "w") as f:
        # first line is header: Start (s),End (s),Scientific name,Common name,Confidence
        f.write("Start (s),End (s),Scientific name,Common name,Confidence\n")
        if pred != "Background":
            # if pred contains _ then split it and use the first part as scientific name and the second part as common name
            if "_" in pred:
                scientific_name, common_name = pred.split("_", 1)
            else:
                scientific_name = pred
                common_name = pred
            f.write(f"0,3.0,{scientific_name},{common_name},1\n")

print("Predictions saved to the 'predictions' folder")
# Out:
# Predictions saved to the 'predictions' folder

# %%
# print all csv filename in predict_test_model12_conf015 sorted alphabetically
for file_name in sorted(os.listdir(test_folder)):
    if file_name.endswith(".WAV"):
        print(file_name)
# Out:
# AM10_20230509_063000_21.77_23.40_0.18.WAV
# AM10_20230509_090000_0.01_1.03_0.16.WAV
# AM10_20230509_090000_1.79_3.22_0.19.WAV
# AM10_20230509_090000_13.00_14.38_0.20.WAV
# AM10_20230509_090000_19.78_20.83_0.16.WAV
# AM10_20230509_090000_23.78_25.38_0.16.WAV
# AM10_20230509_090000_31.95_32.46_0.22.WAV
# AM10_20230509_090000_36.93_38.23_0.15.WAV
# AM10_20230509_090000_49.04_50.29_0.18.WAV
# AM10_20230509_090000_5.47_6.95_0.30.WAV
# AM10_20230509_090000_52.85_53.90_0.28.WAV
# AM10_20230509_090000_58.66_59.97_0.19.WAV
# AM10_20230523_063000_0.00_0.88_0.17.WAV
# AM10_20230523_063000_11.74_13.34_0.40.WAV
# AM10_20230523_063000_18.33_19.56_0.62.WAV
# AM10_20230523_063000_2.42_3.88_0.18.WAV
# AM10_20230523_063000_24.40_25.89_0.73.WAV
# AM10_20230523_063000_30.41_31.32_0.23.WAV
# AM10_20230523_063000_32.95_34.51_0.79.WAV
# AM10_20230523_063000_45.84_47.01_0.18.WAV
# AM10_20230523_063000_5.74_6.93_0.30.WAV
# AM10_20230523_063000_50.13_51.67_0.55.WAV
# AM10_20230523_063000_51.25_53.21_0.25.WAV
# AM10_20230523_063000_53.93_55.37_0.45.WAV
# AM10_20230523_070000_0.00_1.70_0.61.WAV
# AM10_20230523_070000_11.70_13.43_0.75.WAV
# AM10_20230523_070000_16.09_17.23_0.32.WAV
# AM10_20230523_070000_18.11_19.79_0.15.WAV
# AM10_20230523_070000_20.48_21.85_0.40.WAV
# AM10_20230523_070000_21.14_24.16_0.15.WAV
# AM10_20230523_070000_24.87_26.22_0.27.WAV
# AM10_20230523_070000_26.66_28.03_0.16.WAV
# AM10_20230523_070000_28.92_30.77_0.86.WAV
# AM10_20230523_070000_3.27_4.45_0.29.WAV
# AM10_20230523_070000_33.85_35.19_0.40.WAV
# AM10_20230523_070000_40.11_41.38_0.39.WAV
# AM10_20230523_070000_44.18_45.76_0.72.WAV
# AM10_20230523_070000_55.72_56.41_0.28.WAV
# AM10_20230523_070000_57.42_58.56_0.26.WAV
# AM10_20230523_070000_58.76_59.99_0.22.WAV
# AM10_20230523_070000_6.88_8.21_0.36.WAV
# AM10_20230718_063000_1.39_2.78_0.36.WAV
# AM10_20230718_063000_10.48_13.40_0.15.WAV
# AM10_20230718_063000_15.89_17.20_0.21.WAV
# AM10_20230718_063000_24.86_26.11_0.23.WAV
# AM10_20230718_063000_34.42_35.58_0.23.WAV
# AM10_20230718_063000_38.09_39.42_0.23.WAV
# AM10_20230718_063000_45.27_47.34_0.48.WAV
# AM10_20230718_063000_7.93_9.56_0.53.WAV
# AM10_20230718_065000_0.09_2.63_0.54.WAV
# AM10_20230718_065000_23.88_26.39_0.15.WAV
# AM10_20230718_070000_0.04_2.47_0.22.WAV
# AM10_20230718_070000_23.95_24.99_0.28.WAV
# AM10_20230718_070000_25.62_29.09_0.21.WAV
# AM10_20230718_070000_31.50_32.92_0.32.WAV
# AM10_20230718_070000_36.88_38.18_0.17.WAV
# AM10_20230718_070000_41.90_43.07_0.16.WAV
# AM10_20230718_070000_44.86_48.26_0.17.WAV
# AM10_20230718_070000_49.34_50.55_0.17.WAV
# AM10_20230718_070000_53.43_56.01_0.17.WAV
# AM10_20230718_070000_58.09_59.97_0.16.WAV
# AM10_20230718_071000_0.05_1.90_0.28.WAV
# AM10_20230718_071000_19.90_20.98_0.18.WAV
# AM10_20230718_071000_26.90_29.07_0.20.WAV
# AM10_20230718_071000_30.95_32.14_0.18.WAV
# AM10_20230718_071000_32.27_34.92_0.20.WAV
# AM10_20230718_071000_36.31_37.29_0.15.WAV
# AM10_20230718_071000_38.06_39.53_0.51.WAV
# AM10_20230718_071000_42.65_44.68_0.37.WAV
# AM10_20230718_071000_56.82_57.83_0.15.WAV
# AM10_20230718_071000_7.42_8.42_0.51.WAV
# AM10_20230718_073000_50.85_52.00_0.15.WAV
# AM10_20230718_074000_0.01_2.46_0.19.WAV
# AM10_20230718_074000_13.74_15.63_0.16.WAV
# AM10_20230718_074000_16.19_17.54_0.33.WAV
# AM10_20230718_074000_2.42_6.26_0.42.WAV
# AM10_20230718_074000_20.17_23.48_0.46.WAV
# AM10_20230718_074000_30.44_32.37_0.37.WAV
# AM10_20230718_074000_37.32_38.83_0.18.WAV
# AM10_20230718_074000_40.89_42.80_0.22.WAV
# AM10_20230718_074000_42.88_46.52_0.36.WAV
# AM10_20230718_082000_11.19_13.50_0.21.WAV
# AM10_20230718_082000_2.18_5.68_0.15.WAV
# AM10_20230718_082000_21.55_23.74_0.23.WAV
# AM10_20230718_082000_30.77_33.02_0.25.WAV
# AM10_20230718_082000_39.71_42.14_0.25.WAV
# AM10_20230718_082000_48.48_49.72_0.31.WAV
# AM10_20230718_082000_50.36_52.54_0.19.WAV
# AM10_20230718_082000_57.62_58.57_0.29.WAV
# AM10_20230718_093000_49.88_51.67_0.59.WAV
# AM10_20230718_093000_52.39_54.12_0.41.WAV
# AM10_20230718_100000_34.65_39.31_0.35.WAV
# AM10_20230718_100000_46.08_47.77_0.26.WAV
# AM10_20230718_101000_16.35_19.44_0.43.WAV
# AM11_20230303_060000_2.32_3.88_0.42.WAV
# AM11_20230303_060000_9.42_10.12_0.22.WAV
# AM11_20230303_063000_12.89_17.71_0.47.WAV
# AM11_20230303_063000_26.91_28.60_0.38.WAV
# AM11_20230303_063000_31.67_32.76_0.15.WAV
# AM11_20230303_063000_38.97_40.61_0.16.WAV
# AM11_20230303_063000_41.74_43.73_0.69.WAV
# AM11_20230303_063000_46.51_47.53_0.19.WAV
# AM11_20230303_063000_51.01_52.18_0.25.WAV
# AM11_20230303_063000_9.96_11.21_0.31.WAV
# AM11_20230530_063000_0.00_0.96_0.36.WAV
# AM11_20230530_063000_7.81_9.05_0.15.WAV
# AM11_20230530_065000_0.00_7.59_0.44.WAV
# AM11_20230530_065000_16.24_20.75_0.19.WAV
# AM11_20230530_071000_0.00_3.84_0.18.WAV
# AM11_20230530_071000_0.57_60.00_0.64.WAV
# AM11_20230530_071000_12.23_14.71_0.29.WAV
# AM11_20230530_074000_0.25_2.01_0.27.WAV
# AM11_20230530_074000_11.27_13.21_0.32.WAV
# AM11_20230530_074000_28.15_30.07_0.53.WAV
# AM11_20230530_074000_5.66_7.44_0.57.WAV
# AM11_20230530_081000_31.35_35.46_0.38.WAV
# AM11_20230530_102000_0.00_3.13_0.15.WAV
# AM15_20230330_063000_26.45_28.41_0.38.WAV
# AM15_20230330_063000_31.49_33.53_0.50.WAV
# AM15_20230330_063000_43.40_44.90_0.17.WAV
# AM15_20230330_063000_44.53_46.36_0.49.WAV
# AM15_20230330_063000_49.35_50.92_0.26.WAV
# AM15_20230330_063000_57.23_58.46_0.17.WAV
# AM15_20230330_063000_7.96_9.52_0.20.WAV
# AM15_20230330_070000_0.00_0.92_0.34.WAV
# AM15_20230330_070000_15.88_17.07_0.22.WAV
# AM15_20230330_070000_24.23_26.18_0.16.WAV
# AM15_20230330_070000_33.39_34.15_0.23.WAV
# AM15_20230330_070000_40.55_42.50_0.16.WAV
# AM15_20230330_070000_43.87_44.78_0.17.WAV
# AM1_20230510_080000_44.94_46.35_0.27.WAV
# AM1_20230510_083000_15.04_15.99_0.16.WAV
# AM1_20230510_083000_17.69_21.92_0.44.WAV
# AM1_20230510_083000_24.22_26.08_0.52.WAV
# AM1_20230510_083000_28.74_30.30_0.40.WAV
# AM1_20230510_083000_35.53_36.89_0.16.WAV
# AM1_20230510_083000_46.59_47.44_0.30.WAV
# AM1_20230510_083000_50.67_52.82_0.60.WAV
# AM1_20230510_083000_57.33_58.47_0.41.WAV
# AM1_20230511_060000_0.00_0.84_0.26.WAV
# AM1_20230511_060000_1.71_2.62_0.29.WAV
# AM1_20230511_060000_14.87_16.63_0.51.WAV
# AM1_20230511_060000_20.51_23.57_0.75.WAV
# AM1_20230511_060000_29.40_30.87_0.70.WAV
# AM1_20230511_060000_34.14_35.33_0.60.WAV
# AM1_20230511_060000_38.88_40.49_0.56.WAV
# AM1_20230511_060000_44.77_47.09_0.52.WAV
# AM1_20230511_060000_49.50_50.66_0.62.WAV
# AM1_20230511_060000_5.74_8.88_0.48.WAV
# AM1_20230511_060000_51.39_53.09_0.31.WAV
# AM1_20230511_060000_54.90_56.22_0.24.WAV
# AM1_20230511_063000_20.03_20.76_0.19.WAV
# AM1_20230511_063000_53.42_56.47_0.20.WAV
# AM1_20230511_090000_1.84_3.23_0.20.WAV
# AM1_20230511_090000_13.64_14.99_0.43.WAV
# AM1_20230511_090000_28.08_29.51_0.21.WAV
# AM1_20230511_090000_6.04_7.29_0.17.WAV
# AM1_20230511_093000_32.97_35.07_0.44.WAV
# AM1_20230511_093000_38.74_40.54_0.56.WAV
# AM1_20230511_093000_44.08_45.88_0.69.WAV
# AM1_20230511_093000_48.60_50.94_0.34.WAV
# AM1_20230511_093000_54.20_56.24_0.78.WAV
# AM1_20230511_093000_59.07_59.98_0.18.WAV
# AM1_20230511_103000_0.21_2.26_0.23.WAV
# AM1_20230511_103000_40.72_42.48_0.24.WAV
# AM1_20230511_103000_49.06_50.60_0.51.WAV
# AM1_20230511_103000_8.11_10.22_0.42.WAV
# AM1_20230512_083000_22.18_23.36_0.35.WAV
# AM1_20230512_090000_0.01_1.44_0.64.WAV
# AM1_20230512_090000_10.85_12.12_0.21.WAV
# AM1_20230512_090000_15.62_16.55_0.21.WAV
# AM1_20230512_090000_20.60_22.01_0.80.WAV
# AM1_20230512_090000_25.76_27.45_0.60.WAV
# AM1_20230512_090000_31.75_33.38_0.20.WAV
# AM1_20230512_090000_4.93_6.61_0.67.WAV
# AM1_20230512_090000_40.38_42.01_0.50.WAV
# AM1_20230512_090000_45.49_46.24_0.26.WAV
# AM1_20230512_090000_48.04_50.31_0.76.WAV
# AM1_20230512_090000_56.11_57.33_0.30.WAV
# AM1_20230512_103000_0.02_1.51_0.31.WAV
# AM1_20230512_103000_12.80_14.21_0.19.WAV
# AM1_20230512_103000_2.69_4.92_0.45.WAV
# AM1_20230512_103000_22.46_24.71_0.54.WAV
# AM1_20230512_103000_29.87_32.35_0.75.WAV
# AM1_20230512_103000_35.79_36.91_0.63.WAV
# AM1_20230512_103000_39.53_40.94_0.56.WAV
# AM1_20230512_103000_45.50_46.25_0.30.WAV
# AM1_20230512_103000_47.98_49.25_0.38.WAV
# AM1_20230512_103000_55.95_57.04_0.19.WAV
# AM1_20230514_103000_13.27_15.72_0.77.WAV
# AM1_20230514_103000_16.74_17.66_0.35.WAV
# AM1_20230514_103000_20.63_23.06_0.76.WAV
# AM1_20230514_103000_24.20_25.90_0.32.WAV
# AM1_20230514_103000_3.63_5.94_0.69.WAV
# AM1_20230514_103000_30.02_31.14_0.71.WAV
# AM1_20230514_103000_35.14_36.67_0.34.WAV
# AM1_20230514_103000_9.53_10.70_0.39.WAV
# AM1_20230514_110000_53.62_58.15_0.28.WAV
# AM1_20230515_083000_16.32_17.96_0.23.WAV
# AM1_20230515_083000_28.66_29.96_0.29.WAV
# AM1_20230515_083000_30.08_32.23_0.19.WAV
# AM1_20230515_083000_48.85_50.28_0.22.WAV
# AM1_20230515_090000_28.16_29.81_0.25.WAV
# AM1_20230515_090000_39.02_40.61_0.23.WAV
# AM1_20230515_090000_46.39_47.93_0.58.WAV
# AM1_20230515_090000_52.70_54.24_0.16.WAV
# AM4_20230531_092000_0.02_1.76_0.60.WAV
# AM4_20230531_092000_39.50_41.28_0.47.WAV
# AM4_20230531_110000_19.58_21.68_0.59.WAV
# AM8_20230304_070000_0.09_1.27_0.18.WAV
# AM8_20230304_070000_15.68_17.00_0.16.WAV
# AM8_20230304_070000_17.29_31.22_0.27.WAV
# AM8_20230304_070000_2.65_6.48_0.25.WAV
# AM8_20230304_070000_26.88_28.52_0.36.WAV
# AM8_20230304_070000_29.47_34.35_0.39.WAV
# AM8_20230304_070000_46.04_60.00_0.44.WAV
# AM8_20230304_093000_0.20_5.52_0.71.WAV
# AM8_20230304_093000_19.59_20.99_0.21.WAV
# AM8_20230304_093000_26.75_28.70_0.34.WAV
# AM8_20230304_093000_3.38_60.00_0.54.WAV
# AM8_20230304_093000_31.77_35.04_0.24.WAV
# AM8_20230304_093000_34.96_42.66_0.26.WAV
# AM8_20230304_093000_46.17_49.91_0.28.WAV
# AM8_20230304_093000_50.07_59.94_0.36.WAV
# AM8_20230304_093000_9.10_11.13_0.33.WAV
# AM8_20230304_100000_0.04_1.42_0.17.WAV
# AM8_20230304_100000_18.28_20.71_0.39.WAV
# AM8_20230304_100000_18.92_36.11_0.39.WAV
# AM8_20230304_100000_2.67_16.50_0.42.WAV
# AM8_20230304_100000_28.09_29.01_0.16.WAV
# AM8_20230304_100000_31.78_35.05_0.22.WAV
# AM8_20230304_100000_38.25_40.21_0.39.WAV
# AM8_20230304_100000_40.93_44.27_0.35.WAV
# AM8_20230304_100000_52.93_54.87_0.25.WAV
# AM8_20230304_100000_55.99_60.00_0.42.WAV
# AM8_20230523_064000_0.00_0.94_0.20.WAV
# AM8_20230523_064000_0.02_30.56_0.55.WAV
# AM8_20230523_064000_16.16_18.02_0.23.WAV
# AM8_20230523_064000_18.50_20.27_0.28.WAV
# AM8_20230523_064000_20.87_23.25_0.26.WAV
# AM8_20230523_064000_25.49_27.06_0.33.WAV
# AM8_20230523_064000_27.83_29.24_0.15.WAV
# AM8_20230523_064000_30.84_32.23_0.16.WAV
# AM8_20230523_064000_33.94_35.21_0.36.WAV
# AM8_20230523_064000_36.34_37.92_0.18.WAV
# AM8_20230523_064000_38.94_40.12_0.17.WAV
# AM8_20230523_064000_40.79_42.24_0.17.WAV
# AM8_20230523_064000_42.93_44.16_0.33.WAV
# AM8_20230523_064000_46.73_48.42_0.21.WAV
# AM8_20230523_064000_52.48_53.54_0.17.WAV
# AM8_20230523_064000_55.83_57.20_0.17.WAV
# AM8_20230523_101000_0.00_10.30_0.70.WAV
# AM8_20230523_101000_0.03_1.64_0.37.WAV
# AM8_20230523_101000_13.74_15.07_0.21.WAV
# AM8_20230523_101000_18.88_21.69_0.17.WAV
# AM8_20230523_101000_29.87_31.81_0.46.WAV
# AM8_20230523_101000_32.68_34.48_0.33.WAV
# AM8_20230523_101000_36.26_37.73_0.15.WAV
# AM8_20230523_101000_37.60_40.74_0.26.WAV
# AM8_20230523_101000_41.08_43.63_0.20.WAV
# AM8_20230523_101000_44.08_44.68_0.22.WAV
# AM8_20230523_101000_44.47_46.65_0.54.WAV
# AM8_20230523_101000_52.09_54.57_0.20.WAV
# AM8_20230523_101000_55.81_57.66_0.57.WAV
# AM8_20230523_101000_58.40_60.00_0.29.WAV
# AM8_20230523_101000_9.04_10.52_0.16.WAV

# %%
# !ls ../Data/Dataset/Audios/test/
# Out:
#  AM1   AM10   AM11   AM15   AM4   AM8  'Data Augmentation'

# %%
segment_duration = 3  # Duración de cada segmento en segundos

# Función para preprocesar y ajustar un segmento de audio
def preprocess_segment(audio_segment):
    if len(audio_segment) < target_length:
        padding = target_length - len(audio_segment)
        audio_segment = np.pad(audio_segment, (0, padding), 'constant')
    return audio_segment[:target_length]

# Función para dividir el audio en segmentos de 3 segundos
def split_audio_into_segments(audio_path):
    audio, sr = librosa.load(audio_path, sr=sample_rate)
    segments = []
    for start in range(0, len(audio), target_length):
        segment = audio[start:start + target_length]
        segment = preprocess_segment(segment)
        segments.append(segment)
    return segments

# Carpeta de audios de prueba organizados en subcarpetas
test_folder = "../Data/Dataset/Audios/test/"

# Carpeta de salida para las predicciones
# predictions_folder = "RFPredictions"
predictions_folder = "RGBPredictions"
os.makedirs(predictions_folder, exist_ok=True)

# Procesar cada archivo de audio en cada subcarpeta
for root, _, files in os.walk(test_folder):
    for file_name in files:
        if file_name.endswith(".WAV"):
            audio_path = os.path.join(root, file_name)
            segments = split_audio_into_segments(audio_path)

            # Obtener embeddings y predicciones para cada segmento
            segment_predictions = []
            for i, segment in enumerate(segments):
                embedding = get_embedding(segment)
                # prediction = rf_clf.predict([embedding])[0]  # Predecir usando RandomForest
                prediction = xgb_clf.predict([embedding])[0]

                # decode prediction
                prediction = label_encoder.inverse_transform([prediction])[0]
                
                # Solo agregar predicción si no es "background"
                if prediction != "Background":
                    start_time = i * segment_duration
                    end_time = start_time + segment_duration
                    segment_predictions.append((start_time, end_time, prediction))

            # Guardar predicciones en un archivo CSV replicando la estructura de carpetas
            relative_path = os.path.relpath(audio_path, test_folder)
            output_path = os.path.join(predictions_folder, os.path.dirname(relative_path))
            os.makedirs(output_path, exist_ok=True)
            output_filename = os.path.splitext(file_name)[0] + ".BirdNET.results.csv"
            with open(os.path.join(output_path, output_filename), "w") as f:
                f.write("Start (s),End (s),Scientific name,Common name,Confidence\n")
                for start, end, pred in segment_predictions:
                    if "_" in pred:
                        scientific_name, common_name = pred.split("_", 1)
                    else:
                        scientific_name = common_name = pred
                    f.write(f"{start},{end},{scientific_name},{common_name},1\n")

print("Predictions saved to the 'RFPredictions' folder")
# Out:
# Predictions saved to the 'RFPredictions' folder
