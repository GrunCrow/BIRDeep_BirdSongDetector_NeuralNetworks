#
# File ~/.conda/envs/BIRDeep_TFM_Alba/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/.conda/envs/BIRDeep_TFM_Alba/lib/python3.11/site-packages/ultralytics/engine/validator.py:154, in BaseValidator.__call__(self, trainer, model)
#     152     self.args.rect = False
#     153 self.stride = model.stride  # used in get_dataloader() for padding
# --> 154 self.dataloader = self.dataloader or self.get_dataloader(self.data.get(self.args.split), self.args.batch)
#     156 model.eval()
#     157 model.warmup(imgsz=(1 if pt else self.args.batch, 3, imgsz, imgsz))  # warmup
#
# File ~/.conda/envs/BIRDeep_TFM_Alba/lib/python3.11/site-packages/ultralytics/models/yolo/detect/val.py:225, in DetectionValidator.get_dataloader(self, dataset_path, batch_size)
#     223 def get_dataloader(self, dataset_path, batch_size):
#     224     """Construct and return dataloader."""
# --> 225     dataset = self.build_dataset(dataset_path, batch=batch_size, mode="val")
#     226     return build_dataloader(dataset, batch_size, self.args.workers, shuffle=False, rank=-1)
#
# File ~/.conda/envs/BIRDeep_TFM_Alba/lib/python3.11/site-packages/ultralytics/models/yolo/detect/val.py:221, in DetectionValidator.build_dataset(self, img_path, mode, batch)
#     212 def build_dataset(self, img_path, mode="val", batch=None):
#     213     """
#     214     Build YOLO Dataset.
#     215
#    (...)
#     219         batch (int, optional): Size of batches, this is for `rect`. Defaults to None.
#     220     """
# --> 221     return build_yolo_dataset(self.args, img_path, batch, self.data, mode=mode, stride=self.stride)
#
# File ~/.conda/envs/BIRDeep_TFM_Alba/lib/python3.11/site-packages/ultralytics/data/build.py:88, in build_yolo_dataset(cfg, img_path, batch, data, mode, rect, stride, multi_modal)
#      86 """Build YOLO Dataset."""
#      87 dataset = YOLOMultiModalDataset if multi_modal else YOLODataset
# ---> 88 return dataset(
#      89     img_path=img_path,
#      90     imgsz=cfg.imgsz,
#      91     batch_size=batch,
#      92     augment=mode == "train",  # augmentation
#      93     hyp=cfg,  # TODO: probably add a get_hyps_from_cfg function
#      94     rect=cfg.rect or rect,  # rectangular batches
#      95     cache=cfg.cache or None,
#      96     single_cls=cfg.single_cls or False,
#      97     stride=int(stride),
#      98     pad=0.0 if mode == "train" else 0.5,
#      99     prefix=colorstr(f"{mode}: "),
#     100     task=cfg.task,
#     101     classes=cfg.classes,
#     102     data=data,
#     103     fraction=cfg.fraction if mode == "train" else 1.0,
#     104 )
#
# File ~/.conda/envs/BIRDeep_TFM_Alba/lib/python3.11/site-packages/ultralytics/data/dataset.py:63, in YOLODataset.__init__(self, data, task, *args, **kwargs)
#      61 self.data = data
#      62 assert not (self.use_segments and self.use_keypoints), "Can not use both segments and keypoints."
# ---> 63 super().__init__(*args, **kwargs)
#
# File ~/.conda/envs/BIRDeep_TFM_Alba/lib/python3.11/site-packages/ultralytics/data/base.py:74, in BaseDataset.__init__(self, img_path, imgsz, cache, augment, hyp, prefix, rect, batch_size, stride, pad, single_cls, classes, fraction)
#      72 self.fraction = fraction
#      73 self.im_files = self.get_img_files(self.img_path)
# ---> 74 self.labels = self.get_labels()
#      75 self.update_labels(include_class=classes)  # single_cls and include_class
#      76 self.ni = len(self.labels)  # number of images
#
# File ~/.conda/envs/BIRDeep_TFM_Alba/lib/python3.11/site-packages/ultralytics/data/dataset.py:160, in YOLODataset.get_labels(self)
#     158 # Check if the dataset is all boxes or all segments
#     159 lengths = ((len(lb["cls"]), len(lb["bboxes"]), len(lb["segments"])) for lb in labels)
# --> 160 len_cls, len_boxes, len_segments = (sum(x) for x in zip(*lengths))
#     161 if len_segments and len_boxes != len_segments:
#     162     LOGGER.warning(
#     163         f"WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = {len_segments}, "
#     164         f"len(boxes) = {len_boxes}. To resolve this only boxes will be used and all segments will be removed. "
#     165         "To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset."
#     166     )
#
# ValueError: not enough values to unpack (expected 3, got 0)
