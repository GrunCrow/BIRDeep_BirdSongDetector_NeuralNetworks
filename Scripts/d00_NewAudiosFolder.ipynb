# %%
import os
import pandas as pd
import shutil

# %%
# Directory paths
ROOT_PATH = "../../../desarrollo/"
SOURCE_PATH = os.path.join(ROOT_PATH, "Audio_Data/")
DESTINATION_PATH = os.path.join(ROOT_PATH, "Data/Dataset/Audios/")

CSV_FILE = os.path.join(ROOT_PATH, "Data/Annotations/c01_audio_annotations.csv")

# %%
# Load the CSV file
df = pd.read_csv(CSV_FILE)

# %%
df
# Out:
#                                           path annotator recorder        date  \
# 0       AM4/2023_05_31/AM4_20230531_070000.WAV       Edu      AM4  2023/05/31
# 1       AM4/2023_05_31/AM4_20230531_070000.WAV       Edu      AM4  2023/05/31
# 2       AM4/2023_05_31/AM4_20230531_070000.WAV       Edu      AM4  2023/05/31
# 3       AM4/2023_05_31/AM4_20230531_070000.WAV       Edu      AM4  2023/05/31
# 4       AM4/2023_05_31/AM4_20230531_070000.WAV       Edu      AM4  2023/05/31
# ...                                        ...       ...      ...         ...
# 2494  AM11/2023_03_03/AM11_20230303_100000.WAV    Giulia     AM11  2023/03/03
# 2495  AM11/2023_03_03/AM11_20230303_100000.WAV    Giulia     AM11  2023/03/03
# 2496  AM11/2023_03_03/AM11_20230303_100000.WAV    Giulia     AM11  2023/03/03
# 2497  AM11/2023_03_03/AM11_20230303_100000.WAV    Giulia     AM11  2023/03/03
# 2498  AM11/2023_03_03/AM11_20230303_100000.WAV    Giulia     AM11  2023/03/03
#
#           time  start_time   end_time  low_frequency  high_frequency  \
# 0     07:00:00    0.077542   3.665997    4693.522461     7423.855957
# 1     07:00:00    0.258472   0.766801    2025.144775     3373.662598
# 2     07:00:00    0.784032   1.744687    3047.557617     3628.517334
# 3     07:00:00    1.266513   1.615451    2004.552002     2307.564453
# 4     07:00:00    2.054854   2.937967    2152.036865     3761.862061
# ...        ...         ...        ...            ...             ...
# 2494  10:00:00   46.188592  47.810606     941.181580     4052.858887
# 2495  10:00:00   47.879628  48.367095    1811.169067     2528.704102
# 2496  10:00:00   49.773416  50.178920    3282.733398     3556.380371
# 2497  10:00:00   51.973489  52.963522    4240.234375     5902.258789
# 2498  10:00:00   57.719562  58.215657    5651.845215     7466.805664
#
#                      specie
# 0        cisticola juncidis
# 1                   unknown
# 2     luscinia megarhynchos
# 3                   unknown
# 4                   unknown
# ...                     ...
# 2494      emberiza calandra
# 2495                unknown
# 2496                unknown
# 2497      emberiza calandra
# 2498                unknown
#
# [2499 rows x 10 columns]

# %%
# Count unique paths in df
unique_paths = df["path"].unique()
print(f"Unique paths: {len(unique_paths)}")
# Out:
# Unique paths: 114

# %%
moved_files = set()

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    # Get the source and destination file paths
    parts = row['path'].split("/")
    source_file_path = os.path.join(SOURCE_PATH, parts[0] + "/" + parts[1] + "/Audios/" + parts[2])
    destination_file_path = os.path.join(DESTINATION_PATH, row['path'])

    # Check if the WAV file has already been moved and if it has been moved, skip to next row
    if row['path'] in moved_files:
        continue

    # Create the destination directory if it doesn't exist
    os.makedirs(os.path.dirname(destination_file_path), exist_ok=True)

    # Copy the file
    try:
        shutil.copyfile(source_file_path, destination_file_path)
    except FileNotFoundError:
        print(f"File not found: {source_file_path}")
        continue

    # Update the 'path' value in the DataFrame
    # df.at[index, 'path'] = destination_file_path.split("Audios/")[1]

    # Add the file to the moved files set
    moved_files.add(row['path'])

print(" ================== ")
print(f"Not moved files")
print(" ================== ")

# Filter non_moved_files_df
non_moved_files_df = df[~df['path'].isin(moved_files)]

for index, row in non_moved_files_df.iterrows():
    # Get the source and destination file paths
    parts = row['path'].split("/")
    source_file_path = os.path.join(SOURCE_PATH, parts[0] + "/" + parts[1] + "/Audios/" + parts[2])
    destination_file_path = os.path.join(DESTINATION_PATH, row['path'])

    # Check if the WAV file has already been moved and if it has been moved, skip to next row
    if row['path'] in moved_files:
        continue

    # Create the destination directory if it doesn't exist
    os.makedirs(os.path.dirname(destination_file_path), exist_ok=True)

    # Copy the file
    try:
        shutil.copyfile(source_file_path, destination_file_path)
    except FileNotFoundError:
        print(f"File not found: {source_file_path}")
        continue

# Save the changes to the DataFrame
df.to_csv(CSV_FILE, index=False)
# Out:
# File not found: ../../../desarrollo/Audio_Data/AM1/2023_05_10/Audios/AM1_20230510_110000.WAV
#  ==================
# Not moved files
#  ==================
# File not found: ../../../desarrollo/Audio_Data/AM1/2023_05_10/Audios/AM1_20230510_110000.WAV

# %%
# Delete from df the file AM1_20230510_110000.WAV
#df = df[df['path'] != 'AM1/2023_05_10/Audios/AM1_20230510_110000.WAV']

# df.to_csv(CSV_FILE, index=False)

# %%
# Show length of moved files
# print(f"Moved files: {len(moved_files)}")

# %%
# Save new df as csv

# Path to the folder where you want to save the CSV files
output_file = ROOT_PATH + "Data/Annotations/" + "d00_audio_annotations.csv"

df.to_csv(output_file, index=False)
