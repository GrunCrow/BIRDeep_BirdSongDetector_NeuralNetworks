# %%
import os
import pandas as pd
import shutil

# %%
# Directory paths
ROOT_PATH = "../../../desarrollo/"
SOURCE_PATH = os.path.join(ROOT_PATH, "Audio_Data/")
DESTINATION_PATH = os.path.join(ROOT_PATH, "Data/Dataset/Audios/")

CSV_FILE = os.path.join(ROOT_PATH, "Data/Annotations/c01_audio_annotations.csv")

# %%
# Load the CSV file
df = pd.read_csv(CSV_FILE)

# %%
df
# Out:
#                                           path annotator recorder        date  \
# 0     AM11/2023_03_04/AM11_20230304_083000.WAV       Edu     AM11  2023/03/04
# 1     AM11/2023_03_04/AM11_20230304_083000.WAV       Edu     AM11  2023/03/04
# 2     AM11/2023_03_04/AM11_20230304_083000.WAV       Edu     AM11  2023/03/04
# 3     AM11/2023_03_04/AM11_20230304_083000.WAV       Edu     AM11  2023/03/04
# 4     AM11/2023_03_04/AM11_20230304_083000.WAV       Edu     AM11  2023/03/04
# ...                                        ...       ...      ...         ...
# 3414  AM11/2023_03_03/AM11_20230303_100000.WAV    Giulia     AM11  2023/03/03
# 3415  AM11/2023_03_03/AM11_20230303_100000.WAV    Giulia     AM11  2023/03/03
# 3416  AM11/2023_03_03/AM11_20230303_100000.WAV    Giulia     AM11  2023/03/03
# 3417  AM11/2023_03_03/AM11_20230303_100000.WAV    Giulia     AM11  2023/03/03
# 3418  AM11/2023_03_03/AM11_20230303_100000.WAV    Giulia     AM11  2023/03/03
#
#           time  start_time   end_time  low_frequency  high_frequency  \
# 0     08:30:00    1.238025   3.382138    2830.986328     5333.580320
# 1     08:30:00    2.918202   4.381406    4138.202148     8010.064453
# 2     08:30:00    4.404937   4.598379    3221.859375     4562.120605
# 3     08:30:00    4.546120   6.336018    4345.710938     8010.064453
# 4     08:30:00    5.383198   6.742815    3140.367920     4562.120605
# ...        ...         ...        ...            ...             ...
# 3414  10:00:00   46.188592  47.810606     941.181580     4052.858887
# 3415  10:00:00   47.879628  48.367095    1811.169067     2528.704102
# 3416  10:00:00   49.773416  50.178920    3282.733398     3556.380371
# 3417  10:00:00   51.973489  52.963522    4240.234375     5902.258789
# 3418  10:00:00   57.719562  58.215657    5651.845215     7466.805664
#
#                  specie
# 0      galerida theklae
# 1     emberiza calandra
# 2      galerida theklae
# 3     emberiza calandra
# 4      galerida theklae
# ...                 ...
# 3414  emberiza calandra
# 3415            unknown
# 3416            unknown
# 3417  emberiza calandra
# 3418            unknown
#
# [3419 rows x 10 columns]

# %%
# Count unique paths in df
unique_paths = df["path"].unique()
print(f"Unique paths: {len(unique_paths)}")
# Out:
# Unique paths: 175

# %%
moved_files = set()

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    # Get the source and destination file paths
    parts = row['path'].split("/")
    source_file_path = os.path.join(SOURCE_PATH, parts[0] + "/" + parts[1] + "/Audios/" + parts[2])
    destination_file_path = os.path.join(DESTINATION_PATH, row['path'])

    # Check if the WAV file has already been moved and if it has been moved, skip to next row
    if row['path'] in moved_files:
        continue

    # Create the destination directory if it doesn't exist
    os.makedirs(os.path.dirname(destination_file_path), exist_ok=True)

    # Copy the file
    try:
        shutil.copyfile(source_file_path, destination_file_path)
    except FileNotFoundError:
        print(f"File not found: {source_file_path}")
        continue

    # Update the 'path' value in the DataFrame
    # df.at[index, 'path'] = destination_file_path.split("Audios/")[1]

    # Add the file to the moved files set
    moved_files.add(row['path'])

# Save the changes to the DataFrame
df.to_csv(CSV_FILE, index=False)
# Out:
# File not found: ../../../desarrollo/Audio_Data/AM1/2023_05_10/Audios/AM1_20230510_110000.WAV

# %%
# Show length of moved files
print(f"Moved files: {len(moved_files)}")
# Out:
# Moved files: 174

# %%
# Delete row that contents in path AM1_20230510_110000.WAV
df = df[df['path'] != 'AM1/2023_05_10/AM1_20230510_110000.WAV']

# %%
df
# Out:
#                                           path annotator recorder        date  \
# 0     AM11/2023_03_04/AM11_20230304_083000.WAV       Edu     AM11  2023/03/04
# 1     AM11/2023_03_04/AM11_20230304_083000.WAV       Edu     AM11  2023/03/04
# 2     AM11/2023_03_04/AM11_20230304_083000.WAV       Edu     AM11  2023/03/04
# 3     AM11/2023_03_04/AM11_20230304_083000.WAV       Edu     AM11  2023/03/04
# 4     AM11/2023_03_04/AM11_20230304_083000.WAV       Edu     AM11  2023/03/04
# ...                                        ...       ...      ...         ...
# 3414  AM11/2023_03_03/AM11_20230303_100000.WAV    Giulia     AM11  2023/03/03
# 3415  AM11/2023_03_03/AM11_20230303_100000.WAV    Giulia     AM11  2023/03/03
# 3416  AM11/2023_03_03/AM11_20230303_100000.WAV    Giulia     AM11  2023/03/03
# 3417  AM11/2023_03_03/AM11_20230303_100000.WAV    Giulia     AM11  2023/03/03
# 3418  AM11/2023_03_03/AM11_20230303_100000.WAV    Giulia     AM11  2023/03/03
#
#           time  start_time   end_time  low_frequency  high_frequency  \
# 0     08:30:00    1.238025   3.382138    2830.986328     5333.580320
# 1     08:30:00    2.918202   4.381406    4138.202148     8010.064453
# 2     08:30:00    4.404937   4.598379    3221.859375     4562.120605
# 3     08:30:00    4.546120   6.336018    4345.710938     8010.064453
# 4     08:30:00    5.383198   6.742815    3140.367920     4562.120605
# ...        ...         ...        ...            ...             ...
# 3414  10:00:00   46.188592  47.810606     941.181580     4052.858887
# 3415  10:00:00   47.879628  48.367095    1811.169067     2528.704102
# 3416  10:00:00   49.773416  50.178920    3282.733398     3556.380371
# 3417  10:00:00   51.973489  52.963522    4240.234375     5902.258789
# 3418  10:00:00   57.719562  58.215657    5651.845215     7466.805664
#
#                  specie
# 0      galerida theklae
# 1     emberiza calandra
# 2      galerida theklae
# 3     emberiza calandra
# 4      galerida theklae
# ...                 ...
# 3414  emberiza calandra
# 3415            unknown
# 3416            unknown
# 3417  emberiza calandra
# 3418            unknown
#
# [3418 rows x 10 columns]

# %%
# Save new df as csv

# Path to the folder where you want to save the CSV files
output_file = ROOT_PATH + "Data/Annotations/" + "d00_audio_annotations.csv"

df.to_csv(output_file, index=False)
